# %% [markdown]
# # Resonance vs. Integrator Dynamics in the AMAT Model
#
# This notebook investigates and validates the characteristics of Post-Synaptic Currents (PSCs) in resonators versus integrators using the AMAT model.
#
# Additionally to validating Yamauchi et al., 2011 results, this notebook also compares the native `amat2_psc_exp` implementation with the custom NESTML `amat_neuron` model under **identical inputs and matched parameters**.
#
# ### Difference between integrator vs. resonator PSC behaviour?
# - Integrator Behaviour (All-Pass): Acts like a leaky bucket. It accumulates (sums up) all incoming inputs over time, regardless of their timing. It fires a spike when the total input volume exceeds the threshold. It acts as a low-pass filter, favoring high-frequency bursts or closely packed inputs.
# - Resonator Behaviour (Band-Pass): Acts like a swing. It is highly sensitive to the specific **timing** and **frequency** of inputs. It prefers a specific inter-pulse interval ($\Delta$). If a second pulse arrives at the peak of the internal oscillation caused by the first pulse, the system "resonates" and triggers a spike. If the timing is off, the inputs cancel out.
#
# These firing behaviours are depicted in the figure below

# %% [markdown]
# <img src="images/integrator_resonator.png" width="1050" height="600">

# %%
import nest
import pynestml
import sys
from pathlib import Path
from dataclasses import dataclass
from typing import Literal, Mapping, Sequence
import numpy as np
import matplotlib.pyplot as plt
import importlib
import trace_plotter as tp
from pynestml.codegeneration.nest_code_generator_utils import NESTCodeGeneratorUtils
# Out:
#              -- N E S T --
#
#  Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.9.0-post0.dev14
#  Built  : Jul 16 2026 16:13:29
#
#  This program is provided AS IS and comes with NO WARRANTY.
#  See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %% [markdown]
# # Build and validate the NESTML AMAT neuronal model

# %%
def build_nestml_model(
    source_path: Path,
    module_name: str,) -> tuple[str, str]:
    
    if not source_path.exists():
        raise FileNotFoundError(f"NESTML source not found: {source_path}")

    generated_module, generated_model = NESTCodeGeneratorUtils.generate_code_for( # nest call to compile nestml c++ script 
        str(source_path),
        module_name=module_name,
        logging_level="INFO",)

    try:
        nest.Install(generated_module)
        print(f"Successfully installed module: '{generated_module}'")
    except nest.kernel.NESTError:
        print(f"Module '{generated_module}' is already installed. Skipping installation step.")

    # Verify the MODEL name is loaded and recognized by the NEST engine
    if generated_model not in nest.Models():
        raise RuntimeError(
            f"Generation completed, but model '{generated_model}' is missing from nest.Models()."
        )
    
    # return module, name 
    return generated_module, generated_model

# defining global variables 
nest_model = "amat2_psc_exp"
nestml_source = Path("neurons_nestml/amat_neuron.nestml")
nestml_module = "nestml_amat_module"
resolution_ms = 0.01

# calling build function
module_name, nestml_model = build_nestml_model(
    nestml_source,
    nestml_module,
)

print("Loaded module:", module_name)
print("Generated model:", nestml_model)
print("NESTML recordables:", nest.GetDefaults(nestml_model)["recordables"])
# Out:
# WARNING:root:PyGSL is not available. The stiffness test will be skipped.
# WARNING:root:Error when importing: No module named 'pygsl'
# [1,GLOBAL, INFO]: List of files that will be processed:
# [2,GLOBAL, INFO]: /Users/angusgray/Desktop/JSC/github/jsc_nestml_amat/juypter/neurons_nestml/amat_neuron.nestml
# [3,GLOBAL, INFO]: Target platform code will be generated in directory: "/Users/angusgray/Desktop/JSC/github/jsc_nestml_amat/juypter/target"
# [4,GLOBAL, INFO]: Target platform code will be installed in directory: "/var/folders/jk/36jftn6s3yz6ks1zj2zdlry40000gn/T/nestml_target_ojv53vso"
#
#              -- N E S T --
#
#  Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.9.0-post0.dev14
#  Built  : Jul 16 2026 16:13:29
#
#  This program is provided AS IS and comes with NO WARRANTY.
#  See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.
#
# ...

# %% [markdown]
# ## NEST NESTML parameter config
#
# Building dataclass configs for NESTML and NEST models, with `Frozen=True` and `Literal[]` so the data and variables cannot be influenced and affected in downstream simulations
#
# For instance, mismatch in NESTML, NEST:
# - NESTML expects that offset directly: `omega = 5 mV`.
# - Native NEST exposes `omega` as the **absolute threshold** in its status dictionary, so the equivalent value is `E_L + 5 mV = -65 mV`.

# %%
# restricts so only modeltype can be the following 
ModelType = Literal["nest", "nestml"]

@dataclass(frozen=True) # pass AMATConfig into both nestml and nest configs, ensures params are kept the same 
class AMATConfig:
    pulse_times_ms: tuple[float, ...] = (200.0, 220.0, 400.0, 460.0)
    pulse_amplitude_pa: float = 1000.0
    pulse_width_ms: float = 1.0
    simulation_time_ms: float = 500.0
  
    tau_m_ms: float = 10.0
    gamma: float = 1.5
    B: float = 4.0
    
    E_L_mv = -70.0
    resting_threshold_mv = -65.0
    
    alpha_1_mv: float = 10.0
    alpha_2_mv: float = 0.0

@dataclass
class SimulationResult: # 
    model_name: str
    ModelType: ModelType
    events: Mapping
    spikes: Mapping
    parameters: dict[str, float]

# %% [markdown]
# # Helper functions

# %%
def install_generated_module(module_name: str) -> None:
    """Install the generated module if it is not already loaded.""" # ensure the generated module is in the kernel 
    try:
        nest.Install(module_name)
    except Exception as exc:
        message = str(exc).lower()
        if "loaded already" not in message and "already loaded" not in message: # should be used for nest, nestml will be built and already present. 
            raise

def create_step_current(
    pulse_times_ms: Sequence[float],
    pulse_width_ms: float,
    pulse_amplitude_pa: float,
):
    """Create a rectangular pulse train using one step-current generator."""
    amplitude_times: list[float] = []
    amplitude_values: list[float] = []

    for onset in pulse_times_ms:
        amplitude_times.extend([onset, onset + pulse_width_ms])
        amplitude_values.extend([pulse_amplitude_pa, 0.0])

    return nest.Create(
        "step_current_generator",  # input config for injecting I(e) into the neuron 
        params={
            "amplitude_times": amplitude_times,    # pulse params are stored in the public API  
            "amplitude_values": amplitude_values,    
        },
    )


def identify_model_type(model_name: str, nestml_model_name: str) -> ModelType: 
    if model_name == nest_model:
        return "nest"   # classifying what model we are running for the specified sim
    if model_name == nestml_model_name:
        return "nestml"
    raise ValueError(f"Unsupported AMAT model: {model_name}")


def build_model_parameters(
    model_name: str,
    ModelType: ModelType,
    config: AMATConfig,
) -> dict[str, float]:
    """Translate shared conceptual parameters to each model's public API."""   # public API has a frozen set of params?
    defaults = nest.GetDefaults(model_name)
    tau_m = float(defaults["tau_m"])

    return {
        "tau_m": tau_m,
        "tau_v": config.gamma * tau_m, 
        "beta": config.B / tau_m,
        "alpha_1": config.alpha_1_mv,
        "alpha_2": config.alpha_2_mv,
        "omega": config.resting_threshold_mv,
    }


# available and selected recordables may have different names dep on the nestml/nest config soruce of mismatch errors 
def select_recordables(model_name: str, requested: Sequence[str]) -> list[str]:
    """Keep only quantities actually exposed by the selected model."""
    
    available = set(nest.GetDefaults(model_name)["recordables"])   # collect the recordables available at the nest terminal 
    
    selected = [name for name in requested if name in available]
    missing = [name for name in requested if name not in available]
    
    if missing:
        print(f"{model_name}: unavailable recordables omitted: {missing}")

    return selected

# %%
def run_amat_model(
    model_name: str,
    nestml_model_name: str,
    module_name: str,
    config: AMATConfig,
    *,  #  When you see a bare asterisk * by itself in a function definition, it marks the end of positional arguments and the start of keyword-only arguments
    verbose: bool = True,  #  default verbose true 
) -> SimulationResult:
    """Run one AMAT implementation using the shared experiment definition."""
    
    nest.ResetKernel() # each time an AMAT mdoel is ran reset kernel, clean slate with any pre-existing param values etc. 
    nest.SetKernelStatus({"resolution": resolution_ms})
    nest.set_verbosity("M_ERROR")
    install_generated_module(module_name)

    if model_name not in nest.Models():
        raise RuntimeError(f"Model is not loaded: {model_name}")

    model_type = identify_model_type(model_name, nestml_model_name) # utilising helper functions defined in the cell above 
    parameters = build_model_parameters(model_name, model_type, config)
    neuron = nest.Create(model_name, params=parameters)

    current = create_step_current(
        config.pulse_times_ms, # calling config public times 
        config.pulse_width_ms,
        config.pulse_amplitude_pa,
    )
    nest.Connect(current, neuron)

    spike_recorder = nest.Create("spike_recorder") 
    nest.Connect(neuron, spike_recorder)

    requested_recordables = [ # request all recordables and see what's available? 
        "V_m",
        "V_th",
        "V_th_alpha_1",
        "V_th_alpha_2",
        "V_th_v",
        "V_th_v_aux",
        "I_syn_ex",
        "I_syn_in",
        "I_syn",
    ]
    recordables = select_recordables(model_name, requested_recordables)

    multimeter = nest.Create( # connect all avaialbe recordables to the multimeter 
        "multimeter",
        params={
            "interval": resolution_ms,
            "record_from": recordables,
        },
    )
    
    nest.Connect(multimeter, neuron) # connect multi meter to neuron 
    nest.Simulate(config.simulation_time_ms) # sim

    events = multimeter.get("events")
    spikes = spike_recorder.get("events")

    result_parameters = {
        **parameters,
        "gamma": config.gamma,
        "B": config.B,
        "E_L": config.E_L_mv, # result parameters for plotting and dispaly 
        "resting_threshold": config.resting_threshold_mv,
    }

    if verbose:   # In simulation scripts, it is typically a boolean flag. verbose=true, outputs whereas verbose=false quiet mode 
        print(f"\n{model_name}")
        print("Parameters sent to NEST:", parameters)
        print("Recorded variables:", recordables)
        print("Spike times:", np.asarray(spikes["times"]))
        print(
            "V_m range:",
            f"{np.min(events['V_m']):.6f} to {np.max(events['V_m']):.6f} mV",
        )

    return SimulationResult(
        model_name=model_name,
        ModelType=ModelType,
        events=events,
        spikes=spikes,
        parameters=result_parameters,
    )

# %% [markdown]
# # Mismatch in voltage recordings NEST NESTML
#
# The native model records `V_th` as an absolute voltage. The NESTML model now records the same absolute threshold directly. Native NEST records `I_syn_ex` and `I_syn_in` separately, so total `I_syn` is their sum. Discrete differences that affect the comparision in the output

# %%
def reconstruct_input_current(
    times_ms: np.ndarray,
    config: AMATConfig,
) -> np.ndarray:
    """Reconstruct the known generator command for plotting only."""
    current = np.zeros_like(times_ms, dtype=float) #  create numpty array and fill it with zeros 

    for onset in config.pulse_times_ms:
        active = (
            (times_ms >= onset) #  filling only during spike time
            & (times_ms < onset + config.pulse_width_ms)
        )
        current[active] = config.pulse_amplitude_pa  # fill current arrays with spike times 
    return current #  return the reconsturction I(e) 

def standardise_result(
    result: SimulationResult, # calling public API defined at the start 
    config: AMATConfig, #  config kept the same 
) -> dict[str, np.ndarray]:
    events = result.events
    times = np.asarray(events["times"])
    V_m = np.asarray(events["V_m"])
    zeros = np.zeros_like(V_m)

    I_syn_ex = np.asarray(events.get("I_syn_ex", zeros))
    I_syn_in = np.asarray(events.get("I_syn_in", zeros))
    I_syn = np.asarray(events.get("I_syn", I_syn_ex + I_syn_in))  # call in I_syn_ex, I_syn_in is there different naming conventions? 

    if "V_th" in events:
        theta = np.asarray(events["V_th"])
    else:
        theta = (
            config.E_L_mv
            + config.omega_offset_mv
            + np.asarray(events.get("V_th_alpha_1", zeros))
            + np.asarray(events.get("V_th_alpha_2", zeros))
            + np.asarray(events.get("V_th_v", zeros))
        )

    return {
        "times": times,
        "input_current": reconstruct_input_current(times, config),  #  calling the reconsturction function above 
        "V_m": V_m,
        "theta": theta,
        "distance": V_m - theta,  #  distance from the membrane to the threshold 
        "V_th_v": np.asarray(events.get("V_th_v", zeros)),
        "I_syn_ex": I_syn_ex, #  newly created PSC variables 
        "I_syn_in": I_syn_in,  # 
        "I_syn": I_syn,  # 
    }

# %% [markdown]
# # Simulate and compare NEST NESTML
#
# Both AMAT models now receive the same pulse times, pulse width, pulse amplitude, simulation resolution and AMAT parameters. Errors should be 0.

# %%
def compare_trace( # compare trace function, taking in two traces 
    name: str,
    left: np.ndarray,
    right: np.ndarray,
) -> dict[str, float]:
    
    if left.shape != right.shape:
        raise ValueError(
            f"{name}: incompatible shapes {left.shape} and {right.shape}" # incompabile trace to compare 
        )

    error = right - left
    metrics = {
        "max_abs_error": float(np.max(np.abs(error))),
        "mean_abs_error": float(np.mean(np.abs(error))),
        "rmse": float(np.sqrt(np.mean(error**2))),
    }

    print( # 6g = standard format, 12s format strings to a fixed width of 12 characters
        f"{name:12s} | "
        f"max |Δ|={metrics['max_abs_error']:.6g} | "  # maximum offset found across timepoints 
        f"MAE={metrics['mean_abs_error']:.6g} | "  # mean across the timepoints this will catch anyoffset
        f"RMSE={metrics['rmse']:.6g}" # squares every error value before averging them and taking the sqr root, penalises large deviations
    )
    return metrics

config = AMATConfig() # establish amat config 

native_result = run_amat_model(
    nest_model,
    nestml_model,
    module_name,
    config,
)

nestml_result = run_amat_model(
    nestml_model,
    nestml_model,
    module_name,
    config,
)

native = standardise_result(native_result, config)
print("Native NEST simulation finished.")
generated = standardise_result(nestml_result, config)
print("NESTML simulation finished.") 

assert np.allclose(native["times"], generated["times"])

comparison_metrics = {
    name: compare_trace(name, native[name], generated[name])
    for name in ["V_m", "theta", "V_th_v", "I_syn"]
}

print("\nSpike times")
print("Native :", np.asarray(native_result.spikes["times"]))
print("NESTML :", np.asarray(nestml_result.spikes["times"]))
# Out:
# amat2_psc_exp: unavailable recordables omitted: ['V_th_alpha_1', 'V_th_alpha_2', 'V_th_v_aux', 'I_syn'][INFO] [2026-07-29 12:52:23] Temporal resolution changed from 0.1 to 0.01 ms.
#
#
# amat2_psc_exp
# Parameters sent to NEST: {'tau_m': 10.0, 'tau_v': 15.0, 'beta': 0.4, 'alpha_1': 10.0, 'alpha_2': 0.0, 'omega': -65.0}
# Recorded variables: ['V_m', 'V_th', 'V_th_v', 'I_syn_ex', 'I_syn_in']
# Spike times: [461.88]
# V_m range: -70.000000 to -64.597928 mV
#
# amat_neuron_nestml
# Parameters sent to NEST: {'tau_m': 10.0, 'tau_v': 15.0, 'beta': 0.4, 'alpha_1': 10.0, 'alpha_2': 0.0, 'omega': -65.0}
# Recorded variables: ['V_m', 'V_th', 'V_th_alpha_1', 'V_th_alpha_2', 'V_th_v', 'V_th_v_aux', 'I_syn_ex', 'I_syn_in', 'I_syn']
# Spike times: [461.88]
# V_m range: -70.000000 to -64.597928 mV
# /Users/angusgray/Desktop/JSC/nest-simulator/mamba/lib/python3.12/site-packages/nest/lib/hl_api_helper.py:111: UserWarning:
# ...

# %% [markdown]
# # Overlap NESTML NEST Plot
#
# Solid lines show native NEST; dashed lines show NESTML. The bottom row displays the direct difference `NESTML − native`.

# %%
def plot_model_comparison_overlap(
    native: Mapping[str, np.ndarray],
    generated: Mapping[str, np.ndarray],
    *,
    xlim: tuple[float, float] | None = None,
):
    
    trace_info = [
        ("input_current", "Injected current", "pA"),  # key, title, unit
        ("V_m", "Membrane potential", "mV"),
        ("theta", r"Summed threshold: $\theta=E_L+\omega+\theta_{\alpha_1}+\theta_{\alpha_2}+\theta_v$", "mV"),
        ("V_th_v", r"Voltage-dependent threshold: $\theta_v=\beta \int K(s)\dot{V}(t-s)\,ds$", "mV"),    
        ("I_syn", "Total postsynaptic current", "pA"),
        ("distance", r"Spike proximity: $V_m-\theta(t)$", "mV"),
    ]

    fig, axes = plt.subplots(
        len(trace_info) + 1,
        1,
        figsize=(12, 13),
        sharex=True,
    )

    time = native["times"]

    for ax, (key, title, unit) in zip(axes[:-1], trace_info):
        ax.plot(time, native[key], label="Native NEST", linewidth=1.5)
        ax.plot(
            time,
            generated[key],
            "--",
            label="NESTML",
            linewidth=1.2,
        )
        ax.set_ylabel(unit)
        ax.set_title(title, loc="left")
        ax.grid(True, linestyle=":", alpha=0.35)

    difference = generated["V_m"] - native["V_m"]
    axes[-1].plot(time, difference)
    axes[-1].axhline(0.0, linestyle=":", linewidth=1.0)
    axes[-1].set_title("V_m difference: NESTML − native", loc="left")
    axes[-1].set_ylabel("mV")
    axes[-1].set_xlabel("Time (ms)")
    axes[-1].grid(True, linestyle=":", alpha=0.35)

    if xlim is not None:
        axes[-1].set_xlim(*xlim)

    axes[0].legend()
    fig.tight_layout()
    return fig, axes

plot_model_comparison_overlap(native, generated)
plt.show()

# %% [markdown]
# # Side-by-side NESTML NEST Plot
#
# Here we display a greater variety of firing behaviours and characteristics

# %%
def plot_model_comparison_split(
    native: Mapping[str, np.ndarray],
    generated: Mapping[str, np.ndarray],
    *,
    xlim: tuple[float, float] | None = None,
):
    trace_info = [
        ("input_current", "Injected current", "pA"),  # key, title, unit
        ("V_m", "Membrane potential", "mV"),
        ("theta", r"Summed threshold: $\theta=E_L+\omega+\theta_{\alpha_1}+\theta_{\alpha_2}+\theta_v$", "mV"),
        ("V_th_v", r"Voltage-dependent threshold: $\theta_v=\beta \int K(s)\dot{V}(t-s)\,ds$", "mV"),    
        ("I_syn", "Total postsynaptic current", "pA"),
        ("distance", r"Spike proximity: $V_m-\theta(t)$", "mV"),
    ]

    # Change to 2 columns (Left: Native NEST, Right: NESTML)
    fig, axes = plt.subplots(
        len(trace_info) + 1,
        2,
        figsize=(14, 14),
        sharex=True,
    )

    time = native["times"]

    # Loop through each row and unpack the left and right columns
    for (ax_left, ax_right), (key, title, unit) in zip(axes[:-1], trace_info):
        # --- Left Column: Native NEST ---
        ax_left.plot(time, native[key], color="#1f77b4", linewidth=1.5)
        ax_left.set_ylabel(unit)
        ax_left.set_title(f"Native: {title}", loc="left", fontsize=10)
        ax_left.grid(True, linestyle=":", alpha=0.35)

        # --- Right Column: NESTML ---
        ax_right.plot(time, generated[key], color="#ff7f0e", linewidth=1.5)
        ax_right.set_ylabel(unit)
        ax_right.set_title(f"NESTML: {title}", loc="left", fontsize=10)
        ax_right.grid(True, linestyle=":", alpha=0.35)

    # --- Bottom Row: V_m Difference / Residuals ---
    difference = generated["V_m"] - native["V_m"]
    
    # Left Box: Difference trace
    axes[-1, 0].plot(time, difference, color="crimson")
    axes[-1, 0].axhline(0.0, linestyle=":", color="black", linewidth=1.0)
    axes[-1, 0].set_title("V_m difference: NESTML − native", loc="left", fontsize=10)
    axes[-1, 0].set_ylabel("mV")
    axes[-1, 0].set_xlabel("Time (ms)")
    axes[-1, 0].grid(True, linestyle=":", alpha=0.35)

    # Right Box: Duplicate difference trace to keep the layout symmetrically clean
    axes[-1, 1].plot(time, difference, color="crimson")
    axes[-1, 1].axhline(0.0, linestyle=":", color="black", linewidth=1.0)
    axes[-1, 1].set_title("V_m difference (aligned view)", loc="left", fontsize=10)
    axes[-1, 1].set_ylabel("mV")
    axes[-1, 1].set_xlabel("Time (ms)")
    axes[-1, 1].grid(True, linestyle=":", alpha=0.35)

    # Set xlim on the bottom row if specified (sharex passes it upwards)
    if xlim is not None:
        axes[-1, 0].set_xlim(*xlim)

    fig.tight_layout()
    return fig, axes

# Call the split function
plot_model_comparison_split(native, generated)
plt.show()

# %%
def plot_model_comparison_split(
    native: Mapping[str, np.ndarray],
    generated: Mapping[str, np.ndarray],
    *,
    xlim: tuple[float, float] | None = None,
):
    trace_info = [
        ("input_current", "Injected current", "pA"),  # key, title, unit
        ("V_m", "Membrane potential", "mV"),
        ("theta", r"Summed threshold: $\theta=E_L+\omega+\theta_{\alpha_1}+\theta_{\alpha_2}+\theta_v$", "mV"),
        ("V_th_v", r"Voltage-dependent threshold: $\theta_v=\beta \int K(s)\dot{V}(t-s)\,ds$", "mV"),    
        ("I_syn", "Total postsynaptic current", "pA"),
        ("distance", r"Spike proximity: $V_m-\theta(t)$", "mV"),
    ]

    # Change to 2 columns (Left: Native NEST, Right: NESTML)
    fig, axes = plt.subplots(
        len(trace_info) + 1,
        2,
        figsize=(14, 14),
        sharex=True,
    )

    time = native["times"]

    # Loop through each row and unpack the left and right columns
    for (ax_left, ax_right), (key, title, unit) in zip(axes[:-1], trace_info):
        # --- Left Column: Native NEST ---
        ax_left.plot(time, native[key], color="#1f77b4", linewidth=1.5)
        ax_left.set_ylabel(unit)
        ax_left.set_title(f"Native: {title}", loc="left", fontsize=10)
        ax_left.grid(True, linestyle=":", alpha=0.35)

        # --- Right Column: NESTML ---
        ax_right.plot(time, generated[key], color="#ff7f0e", linewidth=1.5)
        ax_right.set_ylabel(unit)
        ax_right.set_title(f"NESTML: {title}", loc="left", fontsize=10)
        ax_right.grid(True, linestyle=":", alpha=0.35)

    # --- Bottom Row: V_m Difference / Residuals ---
    difference = generated["V_m"] - native["V_m"]
    
    # Left Box: Difference trace
    axes[-1, 0].plot(time, difference, color="crimson")
    axes[-1, 0].axhline(0.0, linestyle=":", color="black", linewidth=1.0)
    axes[-1, 0].set_title("V_m difference: NESTML − native", loc="left", fontsize=10)
    axes[-1, 0].set_ylabel("mV")
    axes[-1, 0].set_xlabel("Time (ms)")
    axes[-1, 0].grid(True, linestyle=":", alpha=0.35)

    # Right Box: Duplicate difference trace to keep the layout symmetrically clean
    axes[-1, 1].plot(time, difference, color="crimson")
    axes[-1, 1].axhline(0.0, linestyle=":", color="black", linewidth=1.0)
    axes[-1, 1].set_title("V_m difference (aligned view)", loc="left", fontsize=10)
    axes[-1, 1].set_ylabel("mV")
    axes[-1, 1].set_xlabel("Time (ms)")
    axes[-1, 1].grid(True, linestyle=":", alpha=0.35)

    # Set xlim on the bottom row if specified (sharex passes it upwards)
    if xlim is not None:
        axes[-1, 0].set_xlim(*xlim)

    fig.tight_layout()
    return fig, axes

# Call the split function
plot_model_comparison_split(native, generated)
plt.show()

# %% [markdown]
# # ISI Delta Sweep Experiments

# %%
def make_pulse_current(pulse_times, pulse_width, pulse_amplitude):
    amplitude_times = []
    amplitude_values = []

    for t0 in pulse_times:
        amplitude_times.extend([t0, t0 + pulse_width])
        amplitude_values.extend([pulse_amplitude, 0.0])

    return nest.Create(
        "step_current_generator",
        params={
            "amplitude_times": amplitude_times,
            "amplitude_values": amplitude_values,
        },
    )


def run_amat_current(
    model_name,
    pulse_times,
    pulse_amplitude=500.0,
    pulse_width=1.0,
    simtime=500.0,
    gamma=0.5,
    B=0.5,
    alpha_1=10.0,
    alpha_2=0.0,
    verbose=True,
):
    nest.ResetKernel()
    nest.set_verbosity("M_ERROR")

    try:
        nest.Install(module_name)
    except Exception:
        pass
    
    tau_m = nest.GetDefaults(model_name)["tau_m"]
    tau_v = gamma * tau_m
    beta = B / tau_m

    print(f"{model_name} default parameters: {nest.GetDefaults(model_name)}")

    parameters = {
        "alpha_1": alpha_1,
        "alpha_2": alpha_2,
        "beta": beta,
        "tau_v": tau_v,
        "tau_m": tau_m,
        "tau_1": nest.GetDefaults(model_name).get("tau_1", 10.0),
        "tau_2": nest.GetDefaults(model_name).get("tau_2", 200.0),
    }

    neuron = nest.Create(model_name, params=parameters)

    current = make_pulse_current(
        pulse_times=pulse_times,
        pulse_width=pulse_width,
        pulse_amplitude=pulse_amplitude,
    )

    nest.Connect(current, neuron)

    sr = nest.Create("spike_recorder")
    nest.Connect(neuron, sr)

    if model_name == "amat2_psc_exp": # if native NEST

        parameters = {"omega": -65.0} # native nest stores omega relative to E_L
        
        recordables = ["V_m", "V_th", "V_th_v", 
                       "I_syn_ex",  # postsynaptic current for exc
                       "I_syn_in"] # postsynaptic current for inh

    
    else: # else if NESTML
        
        parameters = {"omega": 5.0}  # nestml stores omega and E_L seperately then computes. 
        
        recordables = [
            "V_m",
            "V_th_alpha_1",
            "V_th_alpha_2",
            "V_th_v",
            "V_th_v_aux",
            "I_syn_ex",
            "I_syn_in",
            "I_syn",
        ]

       

    mm = nest.Create(
        "multimeter",
        params={
            "interval": 0.1,
            "record_from": recordables,
        },
    )

    nest.Connect(mm, neuron)
    nest.Simulate(simtime)

    mm_events = mm.get("events")
    sr_events = sr.get("events")

    full_parameters = {
        **parameters,
        "gamma": gamma,
        "B": B,
        "tau_m": tau_m,
        "beta": beta,
        "alpha_1": alpha_1,
        "alpha_2": alpha_2}

    if verbose:
        
        print(f"\n-INFO Statements for: {model_name}")
        print("Parameters:", full_parameters)
        print("Spikes logged:", sr_events["times"])
        print("Vm maximum recorded value:", np.max(mm_events["V_m"]))
        print("Vm minimum recorded value:", np.min(mm_events["V_m"]))

    return mm_events, sr_events, full_parameters


pulse_times = [200.0, 220.0, 400.0, 460.0]

print("\nRunning NESTML AMAT...")
NESTML_AMAT_df, NESTML_AMAT_spikes, NESTML_AMAT_parameters = run_amat_current(
    nestml_model,
    pulse_times=pulse_times,
    pulse_amplitude=1000.0,
    pulse_width=1.0,
    simtime=500.0,
    gamma=1.5,
    B=4.0,
)

print("\nRunning NEST AMAT...")
NEST_AMAT_df, NEST_AMAT_spikes, NEST_AMAT_parameters = run_amat_current(
    "amat2_psc_exp",
    pulse_times=pulse_times,
    pulse_amplitude=1000.0, #  problem with the nest amat model to spike .
    pulse_width=1.0, 
    simtime=500.0,
    gamma=1.5,
    B=4.0,
)
# Out:
# Running NESTML AMAT...
# ...

# %% [markdown]
# # Helper functions for delta experiments

# %%
# Single delta run
def run_delta(
    model_name,
    delta,
    pulse_amplitude=450.0,
    pulse_width=1.0,
    gamma=0.5,
    B=0.5,
    omega=5.0,
    alpha_1=5.0,
    alpha_2=0.0,
    response_window_ms=60.0,
    first_pulse_time=200.0,
):
    pulse_times_delta = [first_pulse_time, first_pulse_time + delta]

    # Important: simtime must extend beyond the second pulse response window.
    simtime = first_pulse_time + delta + response_window_ms + 50.0

    data, spikes, params = run_amat_current(
        model_name,
        pulse_times=pulse_times_delta,
        pulse_amplitude=pulse_amplitude,
        pulse_width=pulse_width,
        simtime=simtime,
        gamma=gamma,
        B=B,
        omega=omega,
        alpha_1=alpha_1,
        alpha_2=alpha_2,
        verbose=False,
    )

    t = data["times"]
    V_m = data["V_m"]
    E_L = nest.GetDefaults(model_name).get("E_L", -70.0)

    theta = (
        E_L
        + params["omega"]
        + data["V_th_alpha_1"]
        + data["V_th_alpha_2"]
        + data["V_th_v"]
    )

    distance = V_m - theta

    second_pulse_time = first_pulse_time + delta
    response_window = (
        (t >= second_pulse_time)
        & (t <= second_pulse_time + response_window_ms)
    )

    if not np.any(response_window):
        raise RuntimeError(
            f"No samples in response window for delta={delta}. "
            f"Increase simtime or reduce response_window_ms."
        )

    max_distance_after_second = np.max(distance[response_window])

    spike_times = spikes["times"]
    spike_after_second = np.any(
        (spike_times >= second_pulse_time)
        & (spike_times <= second_pulse_time + response_window_ms)
    )

    n_spikes_after_second = np.sum(
        (spike_times >= second_pulse_time)
        & (spike_times <= second_pulse_time + response_window_ms)
    )

    return {
        "delta": delta,
        "max_distance_after_second": max_distance_after_second,
        "spike_after_second": spike_after_second,
        "n_spikes_after_second": n_spikes_after_second,
        "data": data,
        "spikes": spikes,
        "distance": distance,
        "theta": theta,
        "params": params,
    }

# Sweep helper
def run_delta_sweep(
    label,
    model_name,
    deltas,
    pulse_amplitude=450.0,
    pulse_width=1.0,
    gamma=0.5,
    B=0.5,
    omega=5.0,
    alpha_1=5.0,
    alpha_2=0.0,
):
    results = [
        run_delta(
            model_name=model_name,
            delta=d,
            pulse_amplitude=pulse_amplitude,
            pulse_width=pulse_width,
            gamma=gamma,
            B=B,
            omega=omega,
            alpha_1=alpha_1,
            alpha_2=alpha_2,
        )
        for d in deltas
    ]

    max_distance = np.array([r["max_distance_after_second"] for r in results])
    spike_after_second = np.array([r["spike_after_second"] for r in results], dtype=bool)
    n_spikes_after_second = np.array([r["n_spikes_after_second"] for r in results])

    return {
        "label": label,
        "params": {
            "pulse_amplitude": pulse_amplitude,
            "pulse_width": pulse_width,
            "gamma": gamma,
            "B": B,
            "omega": omega,
            "alpha_1": alpha_1,
            "alpha_2": alpha_2,
        },
        "deltas": np.asarray(deltas),
        "results": results,
        "max_distance": max_distance,
        "spike_after_second": spike_after_second,
        "n_spikes_after_second": n_spikes_after_second,
    }


# Simple sweep classifier, whether the spikes after second are resonator/integrator like characteristics ...
def classify_sweep(sweep):
    deltas = sweep["deltas"]
    max_distance = sweep["max_distance"]
    spike_after_second = sweep["spike_after_second"]

    peak_idx = np.argmax(max_distance)
    peak_delta = deltas[peak_idx]
    peak_value = max_distance[peak_idx]

    left_edge = max_distance[0]
    right_edge = max_distance[-1]
    edge_value = max(left_edge, right_edge)

    selectivity = peak_value - edge_value

    spike_fraction = np.mean(spike_after_second)

    # Ratio: peak compared with early close-pulse response.
    short_delta_value = max_distance[0]
    peak_over_short = peak_value - short_delta_value

    if spike_fraction > 0.6:
        label = "broad spiking / too excitable"
    elif spike_fraction == 0 and selectivity > 0.3:
        label = "subthreshold resonator-like"
    elif 0 < spike_fraction <= 0.5 and selectivity > 0.3:
        label = "spiking resonator-like"
    elif short_delta_value >= peak_value - 0.15:
        label = "integrator-like / strongest at short Δ"
    else:
        label = "ambiguous"

    return {
        "label": label,
        "peak_delta": peak_delta,
        "peak_value": peak_value,
        "selectivity": selectivity,
        "spike_fraction": spike_fraction,
        "peak_over_short": peak_over_short,
    }

# Plotting helper
def plot_sweep_comparison(sweeps, title):
    fig, axes = plt.subplots(
        3,
        1,
        figsize=(9, 8),
        sharex=True,
        gridspec_kw={"height_ratios": [2.2, 1.0, 1.0]},
    )

    for sweep in sweeps:
        deltas = sweep["deltas"]
        label = sweep["label"]

        axes[0].plot(
            deltas,
            sweep["max_distance"],
            label=label,
            lw=1.8,
        )

        axes[1].plot(
            deltas,
            sweep["spike_after_second"].astype(int),
            label=label,
            lw=1.5,
        )

        axes[2].plot(
            deltas,
            sweep["n_spikes_after_second"],
            label=label,
            lw=1.5,
        )

    axes[0].axhline(0, linestyle="--")
    axes[0].set_ylabel(r"max post-second-pulse $V_m-\theta$ (mV)")
    axes[0].set_title(title)
    axes[0].legend()

    axes[1].set_ylabel("Spike?")
    axes[1].set_yticks([0, 1])

    axes[2].set_ylabel("Spike count")
    axes[2].set_xlabel(r"Inter-pulse interval $\Delta$ (ms)")

    for ax in axes:
        ax.grid(True, linestyle=":", alpha=0.4)

    plt.tight_layout()
    plt.show()

    for sweep in sweeps:
        summary = classify_sweep(sweep)
        print(f"\n{sweep['label']}")
        print("Parameters:", sweep["params"])
        print("Classification:", summary["label"])
        print(f"Peak Δ: {summary['peak_delta']:.1f} ms")
        print(f"Peak max(V_m - theta): {summary['peak_value']:.3f} mV")
        print(f"Selectivity vs edges: {summary['selectivity']:.3f} mV")
        print(f"Spike fraction: {summary['spike_fraction']:.1%}")

# %% [markdown]
# # B=0 Ablation Delta sweep

# %%
# defining delta range 
deltas = np.arange(2.0, 150.0, 2.0)

integrator_sweep = run_delta_sweep(
    label="Integrator-like control: B=0",
    model_name=nestml_model,
    deltas=deltas,
    pulse_amplitude=450.0,
    pulse_width=1.0,
    gamma=0.5,
    B=0.0,
    alpha_1=5.0,
    alpha_2=0.0,
)

plot_sweep_comparison(
    [integrator_sweep],
    title="Integrator-like pulse-pair response"
)

candidate_sweeps = []
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 # defining delta range
#       2 deltas = np.arange(2.0, 150.0, 2.0)
#       3
# ----> 4 integrator_sweep = run_delta_sweep(
#       5     label="Integrator-like control: B=0",
#       6     model_name=nestml_model,
#       7     deltas=deltas,
#
# Cell In[19], line 98, in run_delta_sweep(label, model_name, deltas, pulse_amplitude, pulse_width, gamma, B, omega, alpha_1, alpha_2)
#      94     omega=5.0,
#      95     alpha_1=5.0,
#      96     alpha_2=0.0,
#      97 ):
# ---> 98     results = [
#      99         run_delta(
#     100             model_name=model_name,
#     101             delta=d,
#
# Cell In[19], line 20, in run_delta(model_name, delta, pulse_amplitude, pulse_width, gamma, B, omega, alpha_1, alpha_2, response_window_ms, first_pulse_time)
#      16
# ...

# %% [markdown]
# # Finding optimal parameter for resonant behaviour

# %%
for B_value in [0.5, 1.0, 2.0, 4.0]:
    for gamma_value in [0.25, 0.5, 1.0, 1.5]:
        sweep = run_delta_sweep(
            label=rf"AMAT: B={B_value}, $\gamma$={gamma_value}",
            model_name=neuron_model_name,
            deltas=deltas,
            pulse_amplitude=450.0,
            pulse_width=1.0,
            gamma=gamma_value,
            B=B_value,
            alpha_1=5.0,
            alpha_2=0.0,
        )

        summary = classify_sweep(sweep)

        candidate_sweeps.append((summary, sweep))

# Sort by selectivity: biggest band-pass-like response first
candidate_sweeps = sorted(
    candidate_sweeps,
    key=lambda x: x[0]["selectivity"],
    reverse=True,
)

print("Top candidate resonator sweeps:")
for summary, sweep in candidate_sweeps[:5]:
    print(
        sweep["label"],
        "| class:", summary["label"],
        "| peak Δ:", summary["peak_delta"],
        "| selectivity:", round(summary["selectivity"], 3),
        "| spike fraction:", round(summary["spike_fraction"], 3),
    )

best_summary, best_resonator_sweep = candidate_sweeps[0]

plot_sweep_comparison(
    [integrator_sweep, best_resonator_sweep],
    title="Integrator-like MAT control vs AMAT resonator candidate"
)

# %% [markdown]
# # Sweeping the adaptation strength B whilst holding the time-constant gamma

# %%
best_gamma = best_resonator_sweep["params"]["gamma"]

B_sweeps = []

for B_value in [0.0, 0.5, 1.0, 2.0, 4.0]:
    B_sweeps.append(
        run_delta_sweep(
            label=rf"B={B_value}",
            model_name=neuron_model_name,
            deltas=deltas,
            pulse_amplitude=450.0,
            pulse_width=1.0,
            gamma=1.5,
            B=B_value,
            omega=5.0,
            alpha_1=5.0,
            alpha_2=0.0,
        )
    )

plot_sweep_comparison(
    B_sweeps,
    title=rf"Effect of voltage-dependency strength B at $\gamma={best_gamma}$"
)
# Out:
# B=0.0
# Parameters: {'pulse_amplitude': 450.0, 'pulse_width': 1.0, 'gamma': 1.5, 'B': 0.0, 'omega': 5.0, 'alpha_1': 5.0, 'alpha_2': 0.0}
# Classification: spiking resonator-like
# Peak Δ: 18.0 ms
# Peak max(V_m - theta): -0.010 mV
# Selectivity vs edges: 0.301 mV
# Spike fraction: 10.8%
#
# B=0.5
# Parameters: {'pulse_amplitude': 450.0, 'pulse_width': 1.0, 'gamma': 1.5, 'B': 0.5, 'omega': 5.0, 'alpha_1': 5.0, 'alpha_2': 0.0}
# Classification: ambiguous
# Peak Δ: 12.0 ms
# Peak max(V_m - theta): -0.086 mV
# Selectivity vs edges: 0.159 mV
# Spike fraction: 6.8%
#
# B=1.0
# Parameters: {'pulse_amplitude': 450.0, 'pulse_width': 1.0, 'gamma': 1.5, 'B': 1.0, 'omega': 5.0, 'alpha_1': 5.0, 'alpha_2': 0.0}
# Classification: integrator-like / strongest at short Δ
# Peak Δ: 2.0 ms
# Peak max(V_m - theta): -0.228 mV
# Selectivity vs edges: 0.000 mV
# Spike fraction: 4.1%
#
# B=2.0
# ...

# %% [markdown]
# # Sweeping the adaptation time-constant gamma whilst holding adaptation strength

# %%
best_beta = best_resonator_sweep["params"]["B"]

gamma_sweeps = []

for gamma_value in [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 4.0, 5.0]:
    gamma_sweeps.append(
        run_delta_sweep(
            label=rf"gamma={gamma_value}",
            model_name=neuron_model_name,
            deltas=deltas,
            pulse_amplitude=450.0,
            pulse_width=1.0,
            gamma=gamma_value,
            B=3.0,
            omega=5.0,
            alpha_1=5.0,
            alpha_2=0.0,
        )
    )

plot_sweep_comparison(
    gamma_sweeps,
    title=rf"Effect of voltage-dependency strength gamma at $\gamma={best_gamma}$"
)
# Out:
# gamma=0.0
# Parameters: {'pulse_amplitude': 450.0, 'pulse_width': 1.0, 'gamma': 0.0, 'B': 3.0, 'omega': 5.0, 'alpha_1': 5.0, 'alpha_2': 0.0}
# Classification: ambiguous
# Peak Δ: 2.0 ms
# Peak max(V_m - theta): nan mV
# Selectivity vs edges: nan mV
# Spike fraction: 0.0%
#
# gamma=0.5
# Parameters: {'pulse_amplitude': 450.0, 'pulse_width': 1.0, 'gamma': 0.5, 'B': 3.0, 'omega': 5.0, 'alpha_1': 5.0, 'alpha_2': 0.0}
# Classification: integrator-like / strongest at short Δ
# Peak Δ: 12.0 ms
# Peak max(V_m - theta): -0.011 mV
# Selectivity vs edges: 0.034 mV
# Spike fraction: 4.1%
#
# gamma=1.0
# Parameters: {'pulse_amplitude': 450.0, 'pulse_width': 1.0, 'gamma': 1.0, 'B': 3.0, 'omega': 5.0, 'alpha_1': 5.0, 'alpha_2': 0.0}
# Classification: integrator-like / strongest at short Δ
# Peak Δ: 32.0 ms
# Peak max(V_m - theta): -0.091 mV
# Selectivity vs edges: 0.021 mV
# Spike fraction: 0.0%
#
# gamma=1.5
# ...
