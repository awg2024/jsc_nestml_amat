# %% [markdown]
# # Multi-Model Comparison Using the 2009 Quantitative Single-Neuron Modeling Competition Dataset
#
# This notebook is a validation and extension of Figure 3 from the [Kobayashi et al., 2009](https://nih.gov) paper. In this section of the results, the authors utilise the [2009 Quantitative Single-Neuron Modeling Competition (QSNMC) dataset](https://github.com) of cortical neurons, feed these neuronal models biological currents, and compare the biological output against the computational output. The comparison is performed using a coincidence-factor equation detailed below.
#
# ### Assessment of Predictive Performance
#
# The performance of the spike time prediction is assessed with a coefficient measuring the degree of coincidence of a model spike train with a real spike train. Among various methods for measuring the similarity between two spike trains, we adopted here the coincidence factor $\Gamma$ (Jolivet et al., 2004, 2006, 2008a; Kobayashi and Shinomoto, 2007), defined by:
#
# $$ \Gamma = \frac{N_{\text{coinc}} - \langle N_{\text{coinc}} \rangle}{\frac{1}{2}(N_{\text{data}} + N_{\text{model}})} \times \frac{1}{1 - 2\nu\Delta} \quad (5) $$
#
# Where:
# * $N_{\text{data}}$ and $N_{\text{model}}$ represent the numbers of spikes in the experimental data and the computational model, respectively.
# * $N_{\text{coinc}}$ is the number of coincident spikes occurring within an allowable temporal window $\Delta$.
# * $\langle N_{\text{coinc}} \rangle = 2\nu\Delta N_{\text{data}}$ is the expected number of coincidences between the data and random Poisson spikes of the given firing rate $\nu$.
#
# By subtracting $\langle N_{\text{coinc}} \rangle$, the baseline coefficient evaluates to approximately $0$ for mutually independent spike trains. The entire coefficient is normalized by dividing by $1 - 2\nu\Delta$ so that $\Gamma = 1$ if all model spikes successfully coincide within the window $\Delta$. In this study, $\Delta$ is chosen to be $2\text{ ms}$.
#
# Each neuron model was tailored to every biological neuron using sample current–voltage data by maximizing the coincidence score $\Gamma$. The model was then tested with a novel current injection dataset to evaluate its predictive capabilities. The final predictive performance was assessed based on the normalized coincidence scores ($\Gamma'$), relative to the experimental trial-to-trial variation, defined by:
#
# $$ \Gamma' = \frac{\Gamma_{\text{model-experiment}}}{\Gamma_{\text{experiment-experiment}}} \quad (6) $$
#
# I've copied in Figure 3.0 from [Kobayashi et al., 2009] below.

# %% [markdown]
# <img src="images/multi_model_comparision.png" width="1050" height="600">

# %%
# testing imports and mamba env 
import nest
import pynestml
import sys
import numpy as np
import pandas as pd 
import time 
import matplotlib. pyplot as plt 
from pynestml.codegeneration.nest_code_generator_utils import NESTCodeGeneratorUtils

# %%
# biological data spike detection 
def extract_biological_spikes(voltage_trace, dt=0.1, threshold_mv=-10.0):
    """
    Detects spike times (ms) from raw experimental biological voltage data.
    Finds upward crossings where voltage goes from below threshold to above threshold.
    """
    # Convert pandas Series/DataFrames to standard numpy arrays if necessary
    v = np.array(voltage_trace).flatten()
    
    # Locate all indices where the voltage crosses above the threshold
    crossings = np.where((v[:-1] < threshold_mv) & (v[1:] >= threshold_mv))[0]
    
    # Convert index coordinates to exact physical simulation time stamps (ms)
    # Adding 1 aligns it on the grid with the post-crossing value
    biological_spike_times = (crossings + 1) * dt
    return biological_spike_times

def calculate_coincidence_factor_list(models_spikes, data_spikes, duration_ms, delta_ms=2.0):
    """
    Calculates the coincidence factor for multiple models against a single experimental dataset.
    
    Parameters:
    - models_spikes: A list of lists/arrays, where each element contains spike times for a specific model.
    - data_spikes: List/array of experimental data spike times.
    - duration_ms: Total duration of the recording in milliseconds.
    - delta_ms: Temporal tolerance window in milliseconds (default: 2.0).
    
    Returns:
    - A list of float values representing the gamma coincidence factor for each model.
    """
    N_data = len(data_spikes)
    duration_sec = duration_ms / 1000.0
    delta_sec = delta_ms / 1000.0
    
    # Pre-calculate data-dependent constants to save computation time
    if N_data == 0:
        return [0.0] * len(models_spikes)
        
    nu = N_data / duration_sec
    expected_coinc = 2 * nu * delta_sec * N_data
    norm_factor = 1.0 - (2 * nu * delta_sec)
    
    results = []
    
    # Loop through each model's spike train
    for model_spikes in models_spikes:
        N_model = len(model_spikes)
        
        # Check if model is empty or if normalization collapses
        if N_model == 0 or norm_factor <= 0 or (N_data + N_model) == 0:
            results.append(0.0)
            continue
            
        # Count coincidences using a window search
        N_coinc = 0
        matched_indices = set()
        for s_data in data_spikes:
            for i, s_model in enumerate(model_spikes):
                if i not in matched_indices and abs(s_model - s_data) <= delta_ms:
                    N_coinc += 1
                    matched_indices.add(i)
                    break
                    
        # Calculate Gamma coincidence formula
        gamma = ((N_coinc - expected_coinc) / (0.5 * (N_data + N_model))) * (1.0 / norm_factor)
        results.append(max(gamma, 0.0))
        
    return results

# %% [markdown]
# ### Loading and visualising whole dataframe

# %%
# hard coding the file_paths 
current_path = r"2009_competition/data/current.txt"
voltage_path = r"2009_competition/data/voltage_allrep.txt"

# Load current dataframe through pd 
print("Loading current data...")
current_pA = pd.read_csv(current_path, header=None, names=["Current"])

# Fix Voltage loading using regex separator
print("Loading voltage data (parsing multiple columns)...")
# sep=r'\s+' matches one or more spaces or tabs dynamically
voltage = pd.read_csv(voltage_path, header=None, sep=r"\s+")

print(f"Fixed Voltage Shape: {voltage.shape} (Rows, Recording Channels)")
print(f" Current Shape: {current_pA.shape})")

# formatting two subplots  
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Plot Current
ax1.plot(current_pA.index, current_pA["Current"], color="blue", alpha=0.8)
ax1.set_ylabel("Current (pA)")
ax1.set_title("Input Current over Time Steps")
ax1.grid(True, alpha=0.3)

# Plot Voltage (Plots first X channels safely)
channels_to_plot = min(13, voltage.shape[1])
for col in range(channels_to_plot):
    ax2.plot(
        voltage.index,
        voltage.iloc[:, col],
        alpha=0.6,
        label=f"Channel {col}",
    )

ax2.set_xlabel("Time Step / Index")
ax2.set_ylabel("Membrane Potential (mV)")
ax2.set_title(f"Voltage Responses (Showing first {channels_to_plot} channels)")
ax2.grid(True, alpha=0.3)
ax2.legend(loc='right')
plt.tight_layout()
plt.show()
# Out:
# Loading current data...
# Loading voltage data (parsing multiple columns)...
# Fixed Voltage Shape: (390000, 13) (Rows, Recording Channels)
#  Current Shape: (600001, 1))

# %% [markdown]
# ### Segmenting the Dataset
#
# Understanding the neuronal firing characteristics given the injected input (Ia)

# %%
# First X rows of current data (1 column) = Ia 
seg_current = current_pA.iloc[250000:600000, :]

# First X rows of voltage data (incl. all 13 columns) = V_m
seg_voltage_pA = voltage.iloc[250000:600000, :]

print("Voltage segment shape:", seg_current.shape)
print("Current segment shape:", seg_voltage_pA.shape)

# formatting two subplots  
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Plot Current
ax1.plot(seg_current.index, seg_current["Current"], color="blue", alpha=0.8)
ax1.set_ylabel("Current (pA)")
ax1.set_title("Input Current over Time Steps")
ax1.grid(True, alpha=0.3)

# Plot Voltage (Plots first X channels safely)
channels_to_plot = min(13, seg_voltage_pA.shape[1])
for col in range(channels_to_plot):
    ax2.plot(
        seg_voltage_pA.index,
        seg_voltage_pA.iloc[:, col],
        alpha=0.6,
        label=f"Channel {col}",
    )

ax2.set_xlabel("Time Step / Index")
ax2.set_ylabel("Membrane Potential (mV)")
ax2.set_title(f"Voltage Responses (Showing first {channels_to_plot} channels)")
ax2.grid(True, alpha=0.3)
ax2.legend(loc='right')

plt.tight_layout()
plt.show()
# Out:
# Voltage segment shape: (350000, 1)
# Current segment shape: (140000, 13)

# %% [markdown]
# ### Installing NEST Neuronal Models for Conincidence

# %%
# Using sys.prefix targets your active conda-forge environment root directory
nest_path = sys.prefix

# Compile the nestml template file
compiled_mod_name, custom_neuron_name = NESTCodeGeneratorUtils.generate_code_for(
    "neurons_nestml/amat_neuron.nestml",
    module_name="nestml_amat_module",   
    logging_level="INFO", 
)

print(f"[NESTML] Compilation Complete.")
print(f" Dynamically Compiled Module Name: {compiled_mod_name}")
print(f" Target Internal Neuron Name to Instantiate: {custom_neuron_name}")

# Reset the NEST kernel to a completely clean state.
nest.ResetKernel()

# Install your custom dynamic module into the active NEST kernel
nest.Install(compiled_mod_name)

# Only display errors from NEST (suppresses warnings and info messages).
nest.set_verbosity("M_ERROR")

# Configure parameters for the simulation kernel.
nest.SetKernelStatus({"resolution": 0.1, "local_num_threads": 1, "rng_seed": 12345})

print(nest.__version__)
n = nest.Create('mat2_psc_exp')
print("keys for MAT")
print(n.get())
print("---")


# From original paper. 
# Model parameters: HH: C=86pF,g =750nS,g =210nS,g =210nS,g =0.6nS, Na Kd M L
# V =−61mV;LIF:θ=25mV;
# SRM:α=12mV,ω=13mV,τ =50ms; Tα
# MAT*:α =37mV,α =2mV,ω=19mV

# Create the neuron using its internal target name variable
n2 = nest.Create(
    custom_neuron_name,
    params={
        "omega": 5.0,
        "alpha_1": 10.0,
        "alpha_2": 5.0,
        "beta": -5.0,
        # >0 negative feedback
        # <0 positive feedback 
    },
)
print("keys for AMAT")
print(n2.get())
print("---")

n3 = nest.Create('izhikevich')
print("keys for izhikevich")
print(n3.get())
print("---")

n4 = nest.Create('iaf_psc_exp')
print("keys for LIF")
print(list(n4.get().keys()))
print("---")
# Out:
# [1,GLOBAL, INFO]: List of files that will be processed:
# [2,GLOBAL, INFO]: /Users/angusgray/Desktop/JSC/github/jsc_nestml_amat/juypter/neurons_nestml/amat_neuron.nestml
# [3,GLOBAL, INFO]: Target platform code will be generated in directory: "/Users/angusgray/Desktop/JSC/github/jsc_nestml_amat/juypter/target"
# [4,GLOBAL, INFO]: Target platform code will be installed in directory: "/var/folders/jk/36jftn6s3yz6ks1zj2zdlry40000gn/T/nestml_target_24mtpv7x"
#
#              -- N E S T --
#
#  Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.9.0-post0.dev14
#  Built  : Jul 16 2026 16:13:29
#
#  This program is provided AS IS and comes with NO WARRANTY.
#  See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.
#
# [5,GLOBAL, INFO]: The NEST Simulator version was automatically detected as: main
# [6,GLOBAL, INFO]: Given template root path is not an absolute path. Creating the absolute path with default templates directory "/Users/angusgray/Desktop/JSC/nest-simulator/mamba/lib/python3.12/site-packages/pynestml/codegeneration/resources_nest/point_neuron"
# [7,GLOBAL, INFO]: The NEST Simulator installation path was automatically detected as: /Users/angusgray/Desktop/JSC/nest-simulator/mamba
# [8,GLOBAL, INFO]: Start processing "/Users/angusgray/Desktop/JSC/github/jsc_nestml_amat/juypter/neurons_nestml/amat_neuron.nestml"!
# [9,amat_neuron_nestml, INFO, [155:53;155:61]]: Implicit magnitude conversion from pA to pA buffer with factor 1.0
# [10,amat_neuron_nestml, INFO, [155:29;155:44]]: Implicit magnitude conversion from mV / ms to pA / pF with factor 1.0
# INFO:root:Analysing input:
# INFO:root:{
#     "dynamics": [
#         {
#             "expression": "V_th_alpha_1' = (-V_th_alpha_1) / tau_1",
#             "initial_values": {
#                 "V_th_alpha_1": "0"
#             }
#         },
#         {
#             "expression": "V_th_alpha_2' = (-V_th_alpha_2) / tau_2",
#             "initial_values": {
#                 "V_th_alpha_2": "0"
#             }
#         },
#         {
#             "expression": "V_m' = ((-(V_m - E_L)) / tau_m + ((unit_psc * (I_kernel_exc__X__exc_spikes - I_kernel_inh__X__inh_spikes)) + I_e + I_stim) / C_m)",
#             "initial_values": {
#                 "V_m": "E_L"
#             }
#         },
#         {
#             "expression": "V_th_v_aux' = (-V_th_v_aux) / tau_V + beta * ((-(V_m - E_L)) / tau_m + ((unit_psc * (I_kernel_exc__X__exc_spikes - I_kernel_inh__X__inh_spikes)) + I_e + I_stim) / C_m)",
#             "initial_values": {
#                 "V_th_v_aux": "0 / 1.0"
#             }
#         },
#         {
#             "expression": "V_th_v' = (-V_th_v) / tau_V + V_th_v_aux",
#             "initial_values": {
#                 "V_th_v": "0"
#             }
#         },
#         {
#             "expression": "refr_t' = (-1000.0) * 1.0 / 1000.0",
#             "initial_values": {
#                 "refr_t": "0"
#             }
#         },
#         {
#             "expression": "I_kernel_exc__X__exc_spikes = exp(-t / tau_syn_exc)",
#             "initial_values": {}
#         },
#         {
#             "expression": "I_kernel_inh__X__inh_spikes = exp(-t / tau_syn_inh)",
#             "initial_values": {}
#         }
#     ],
#     "options": {
#         "output_timestep_symbol": "__h",
#         "simplify_expression": "sympy.logcombine(sympy.powsimp(sympy.expand(expr)))"
#     },
#     "parameters": {
#         "C_m": "100",
#         "E_L": "(-70)",
#         "I_e": "0",
#         "alpha_1": "37",
#         "alpha_2": "2",
#         "beta": "0 / 1.0",
#         "omega": "19",
#         "refr_T": "2",
#         "tau_1": "10",
#         "tau_2": "200",
#         "tau_V": "5",
#         "tau_m": "10",
#         "tau_syn_exc": "1",
#         "tau_syn_inh": "3"
#     }
# }
# INFO:root:Processing global options...
# INFO:root:Processing input shapes...
# INFO:root:All known variables: [V_th_alpha_1, V_th_alpha_2, V_m, V_th_v_aux, V_th_v, refr_t, I_kernel_exc__X__exc_spikes, I_kernel_inh__X__inh_spikes], all parameters used in ODEs: {C_m, tau_1, I_stim, tau_m, unit_psc, tau_syn_inh, tau_2, beta, tau_V, E_L, tau_syn_exc, I_e}
# INFO:root:No numerical value specified for parameter "I_stim"
# INFO:root:No numerical value specified for parameter "unit_psc"
# INFO:root:Finding analytically solvable equations...
# INFO:root:Saving dependency graph plot to /tmp/ode_dependency_graph.dot
# INFO:root:Saving dependency graph plot to /tmp/ode_dependency_graph_analytically_solvable_before_propagated.dot
# INFO:root:Saving dependency graph plot to /tmp/ode_dependency_graph_analytically_solvable.dot
# INFO:root:Generating propagators for the following symbols: V_th_alpha_1, V_th_alpha_2, V_m, refr_t, I_kernel_exc__X__exc_spikes, I_kernel_inh__X__inh_spikes
# WARNING:root:Under certain conditions, the propagator matrix is singular (contains infinities).
# WARNING:root:List of all conditions that result in a division by zero:
# WARNING:root:	tau_syn_exc = tau_m
# WARNING:root:	tau_syn_inh = tau_m
# INFO:root:Generating numerical solver for the following symbols: V_th_v_aux, V_th_v
# WARNING:root:Not preserving expression for variable "V_th_alpha_1" as it is solved by propagator solver
# WARNING:root:Not preserving expression for variable "V_th_alpha_2" as it is solved by propagator solver
# WARNING:root:Not preserving expression for variable "V_m" as it is solved by propagator solver
# WARNING:root:Not preserving expression for variable "refr_t" as it is solved by propagator solver
# INFO:root:Preserving expression for variable "V_th_v_aux"
# INFO:root:Preserving expression for variable "V_th_v"
# INFO:root:In ode-toolbox: returning outdict =
# INFO:root:[
#     {
#         "initial_values": {
#             "I_kernel_exc__X__exc_spikes": "1",
#             "I_kernel_inh__X__inh_spikes": "1",
#             "V_m": "E_L",
#             "V_th_alpha_1": "0",
#             "V_th_alpha_2": "0",
#             "refr_t": "0"
#         },
#         "parameters": {
#             "C_m": "100.000000000000",
#             "E_L": "-70.0000000000000",
#             "I_e": "0",
#             "tau_1": "10.0000000000000",
#             "tau_2": "200.000000000000",
#             "tau_m": "10.0000000000000",
#             "tau_syn_exc": "1.00000000000000",
#             "tau_syn_inh": "3.00000000000000"
#         },
#         "propagators": {
#             "__P__I_kernel_exc__X__exc_spikes__I_kernel_exc__X__exc_spikes": "exp(-__h/tau_syn_exc)",
#             "__P__I_kernel_inh__X__inh_spikes__I_kernel_inh__X__inh_spikes": "exp(-__h/tau_syn_inh)",
#             "__P__V_m__I_kernel_exc__X__exc_spikes": "tau_m*tau_syn_exc*unit_psc*(-exp(__h/tau_m) + exp(__h/tau_syn_exc))*exp(-__h*(tau_m + tau_syn_exc)/(tau_m*tau_syn_exc))/(C_m*(tau_m - tau_syn_exc))",
#             "__P__V_m__I_kernel_inh__X__inh_spikes": "tau_m*tau_syn_inh*unit_psc*(exp(__h/tau_m) - exp(__h/tau_syn_inh))*exp(-__h*(tau_m + tau_syn_inh)/(tau_m*tau_syn_inh))/(C_m*(tau_m - tau_syn_inh))",
#             "__P__V_m__V_m": "exp(-__h/tau_m)",
#             "__P__V_th_alpha_1__V_th_alpha_1": "exp(-__h/tau_1)",
#             "__P__V_th_alpha_2__V_th_alpha_2": "exp(-__h/tau_2)",
#             "__P__refr_t__refr_t": "1"
#         },
#         "solver": "analytical",
#         "state_variables": [
#             "V_th_alpha_1",
#             "V_th_alpha_2",
#             "V_m",
#             "refr_t",
#             "I_kernel_exc__X__exc_spikes",
#             "I_kernel_inh__X__inh_spikes"
#         ],
#         "update_expressions": {
#             "I_kernel_exc__X__exc_spikes": "I_kernel_exc__X__exc_spikes*__P__I_kernel_exc__X__exc_spikes__I_kernel_exc__X__exc_spikes",
#             "I_kernel_inh__X__inh_spikes": "I_kernel_inh__X__inh_spikes*__P__I_kernel_inh__X__inh_spikes__I_kernel_inh__X__inh_spikes",
#             "V_m": "-E_L*__P__V_m__V_m + E_L + I_kernel_exc__X__exc_spikes*__P__V_m__I_kernel_exc__X__exc_spikes + I_kernel_inh__X__inh_spikes*__P__V_m__I_kernel_inh__X__inh_spikes + V_m*__P__V_m__V_m - I_e*__P__V_m__V_m*tau_m/C_m + I_e*tau_m/C_m - I_stim*__P__V_m__V_m*tau_m/C_m + I_stim*tau_m/C_m",
#             "V_th_alpha_1": "V_th_alpha_1*__P__V_th_alpha_1__V_th_alpha_1",
#             "V_th_alpha_2": "V_th_alpha_2*__P__V_th_alpha_2__V_th_alpha_2",
#             "refr_t": "__P__refr_t__refr_t*refr_t - 1.0*__h"
#         }
#     },
#     {
#         "initial_values": {
#             "V_th_v": "0",
#             "V_th_v_aux": "0"
#         },
#         "parameters": {
#             "C_m": "100.000000000000",
#             "E_L": "-70.0000000000000",
#             "I_e": "0",
#             "beta": "0",
#             "tau_V": "5.00000000000000",
#             "tau_m": "10.0000000000000"
#         },
#         "solver": "numeric",
#         "state_variables": [
#             "V_th_v_aux",
#             "V_th_v"
#         ],
#         "update_expressions": {
#             "V_th_v": "(-V_th_v) / tau_V + V_th_v_aux",
#             "V_th_v_aux": "(-V_th_v_aux) / tau_V + beta * ((-(V_m - E_L)) / tau_m + ((unit_psc * (I_kernel_exc__X__exc_spikes - I_kernel_inh__X__inh_spikes)) + I_e + I_stim) / C_m)"
#         }
#     }
# ]
# INFO:root:Analysing input:
# INFO:root:{
#     "dynamics": [
#         {
#             "expression": "V_th_alpha_1' = (-V_th_alpha_1) / tau_1",
#             "initial_values": {
#                 "V_th_alpha_1": "0"
#             }
#         },
#         {
#             "expression": "V_th_alpha_2' = (-V_th_alpha_2) / tau_2",
#             "initial_values": {
#                 "V_th_alpha_2": "0"
#             }
#         },
#         {
#             "expression": "V_m' = ((-(V_m - E_L)) / tau_m + ((unit_psc * (I_kernel_exc__X__exc_spikes - I_kernel_inh__X__inh_spikes)) + I_e + I_stim) / C_m)",
#             "initial_values": {
#                 "V_m": "E_L"
#             }
#         },
#         {
#             "expression": "V_th_v_aux' = (-V_th_v_aux) / tau_V + beta * ((-(V_m - E_L)) / tau_m + ((unit_psc * (I_kernel_exc__X__exc_spikes - I_kernel_inh__X__inh_spikes)) + I_e + I_stim) / C_m)",
#             "initial_values": {
#                 "V_th_v_aux": "0 / 1.0"
#             }
#         },
#         {
#             "expression": "V_th_v' = (-V_th_v) / tau_V + V_th_v_aux",
#             "initial_values": {
#                 "V_th_v": "0"
#             }
#         },
#         {
#             "expression": "refr_t' = (-1000.0) * 1.0 / 1000.0",
#             "initial_values": {
#                 "refr_t": "0"
#             }
#         },
#         {
#             "expression": "I_kernel_exc__X__exc_spikes = exp(-t / tau_syn_exc)",
#             "initial_values": {}
#         },
#         {
#             "expression": "I_kernel_inh__X__inh_spikes = exp(-t / tau_syn_inh)",
#             "initial_values": {}
#         }
#     ],
#     "options": {
#         "output_timestep_symbol": "__h",
#         "simplify_expression": "sympy.logcombine(sympy.powsimp(sympy.expand(expr)))"
#     },
#     "parameters": {
#         "C_m": "100",
#         "E_L": "(-70)",
#         "I_e": "0",
#         "alpha_1": "37",
#         "alpha_2": "2",
#         "beta": "0 / 1.0",
#         "omega": "19",
#         "refr_T": "2",
#         "tau_1": "10",
#         "tau_2": "200",
#         "tau_V": "5",
#         "tau_m": "10",
#         "tau_syn_exc": "1",
#         "tau_syn_inh": "3"
#     }
# }
# INFO:root:Processing global options...
# INFO:root:Processing input shapes...
# INFO:root:All known variables: [V_th_alpha_1, V_th_alpha_2, V_m, V_th_v_aux, V_th_v, refr_t, I_kernel_exc__X__exc_spikes, I_kernel_inh__X__inh_spikes], all parameters used in ODEs: {C_m, tau_1, I_stim, tau_m, unit_psc, tau_syn_inh, tau_2, beta, tau_V, E_L, tau_syn_exc, I_e}
# INFO:root:No numerical value specified for parameter "I_stim"
# INFO:root:No numerical value specified for parameter "unit_psc"
# INFO:root:Finding analytically solvable equations...
# INFO:root:Saving dependency graph plot to /tmp/ode_dependency_graph.dot
# INFO:root:Saving dependency graph plot to /tmp/ode_dependency_graph_analytically_solvable_before_propagated.dot
# INFO:root:Saving dependency graph plot to /tmp/ode_dependency_graph_analytically_solvable.dot
# INFO:root:Generating numerical solver for the following symbols: I_kernel_inh__X__inh_spikes, V_m, V_th_v_aux, V_th_alpha_1, I_kernel_exc__X__exc_spikes, V_th_v, V_th_alpha_2, refr_t
# INFO:root:Preserving expression for variable "V_th_alpha_1"
# INFO:root:Preserving expression for variable "V_th_alpha_2"
# INFO:root:Preserving expression for variable "V_m"
# INFO:root:Preserving expression for variable "V_th_v_aux"
# INFO:root:Preserving expression for variable "V_th_v"
# INFO:root:Preserving expression for variable "refr_t"
# INFO:root:In ode-toolbox: returning outdict =
# INFO:root:[
#     {
#         "initial_values": {
#             "I_kernel_exc__X__exc_spikes": "1",
#             "I_kernel_inh__X__inh_spikes": "1",
#             "V_m": "E_L",
#             "V_th_alpha_1": "0",
#             "V_th_alpha_2": "0",
#             "V_th_v": "0",
#             "V_th_v_aux": "0",
#             "refr_t": "0"
#         },
#         "parameters": {
#             "C_m": "100.000000000000",
#             "E_L": "-70.0000000000000",
#             "I_e": "0",
#             "beta": "0",
#             "tau_1": "10.0000000000000",
#             "tau_2": "200.000000000000",
#             "tau_V": "5.00000000000000",
#             "tau_m": "10.0000000000000",
#             "tau_syn_exc": "1.00000000000000",
#             "tau_syn_inh": "3.00000000000000"
#         },
#         "solver": "numeric",
#         "state_variables": [
#             "V_th_alpha_1",
#             "V_th_alpha_2",
#             "V_m",
#             "V_th_v_aux",
#             "V_th_v",
#             "refr_t",
#             "I_kernel_exc__X__exc_spikes",
#             "I_kernel_inh__X__inh_spikes"
#         ],
#         "update_expressions": {
#             "I_kernel_exc__X__exc_spikes": "-I_kernel_exc__X__exc_spikes/tau_syn_exc",
#             "I_kernel_inh__X__inh_spikes": "-I_kernel_inh__X__inh_spikes/tau_syn_inh",
#             "V_m": "((-(V_m - E_L)) / tau_m + ((unit_psc * (I_kernel_exc__X__exc_spikes - I_kernel_inh__X__inh_spikes)) + I_e + I_stim) / C_m)",
#             "V_th_alpha_1": "(-V_th_alpha_1) / tau_1",
#             "V_th_alpha_2": "(-V_th_alpha_2) / tau_2",
#             "V_th_v": "(-V_th_v) / tau_V + V_th_v_aux",
#             "V_th_v_aux": "(-V_th_v_aux) / tau_V + beta * ((-(V_m - E_L)) / tau_m + ((unit_psc * (I_kernel_exc__X__exc_spikes - I_kernel_inh__X__inh_spikes)) + I_e + I_stim) / C_m)",
#             "refr_t": "(-1000.0) * 1.0 / 1000.0"
#         }
#     }
# ]
# [11,GLOBAL, INFO]: Starting code generation for model "amat_neuron_nestml"
# [12,amat_neuron_nestml, INFO, [124:0;231:0]]: Starts processing of the model "amat_neuron_nestml"
# [13,GLOBAL, INFO]: Rendering template /Users/angusgray/Desktop/JSC/github/jsc_nestml_amat/juypter/target/amat_neuron_nestml.cpp
# [14,GLOBAL, INFO]: Rendering template /Users/angusgray/Desktop/JSC/github/jsc_nestml_amat/juypter/target/amat_neuron_nestml.h
# [15,amat_neuron_nestml, INFO, [124:0;231:0]]: Successfully generated code for the model: "amat_neuron_nestml" in: "/Users/angusgray/Desktop/JSC/github/jsc_nestml_amat/juypter/target" !
# [16,GLOBAL, INFO]: Rendering template /Users/angusgray/Desktop/JSC/github/jsc_nestml_amat/juypter/target/CMakeLists.txt
# [17,GLOBAL, INFO]: Rendering template /Users/angusgray/Desktop/JSC/github/jsc_nestml_amat/juypter/target/nestml_amat_module.h
# [18,GLOBAL, INFO]: Rendering template /Users/angusgray/Desktop/JSC/github/jsc_nestml_amat/juypter/target/nestml_amat_module.cpp
# [19,GLOBAL, INFO]: Successfully generated NEST module code in "/Users/angusgray/Desktop/JSC/github/jsc_nestml_amat/juypter/target" !
# [NESTML] Compilation Complete.
#  Dynamically Compiled Module Name: nestml_amat_module
#  Target Internal Neuron Name to Instantiate: amat_neuron_nestml
# 3.9.0-post0.dev14
# keys for MAT
# {'C_m': 100.0, 'Ca': 0.0, 'E_L': -70.0, 'I_e': 0.0, 'V_m': -70.0, 'V_th': -51.0, 'V_th_alpha_1': 0.0, 'V_th_alpha_2': 0.0, 'alpha_1': 37.0, 'alpha_2': 2.0, 'archiver_length': 0, 'beta_Ca': 0.001, 'element_type': 'neuron', 'frozen': False, 'global_id': 1, 'ignore_and_spike': False, 'ignore_and_spike_interval': 100.0, 'ignore_and_spike_offset': 1.0, 'local': True, 'model': 'mat2_psc_exp', 'model_id': 67, 'node_uses_wfr': False, 'omega': -51.0, 'post_trace': 0.0, 'recordables': ['V_m', 'V_th'], 'synaptic_elements': {}, 't_ref': 2.0, 't_spike': -1.0, 'tau_1': 10.0, 'tau_2': 200.0, 'tau_Ca': 10000.0, 'tau_m': 5.0, 'tau_minus': 20.0, 'tau_minus_triplet': 110.0, 'tau_syn_ex': 1.0, 'tau_syn_in': 3.0, 'thread': 0, 'thread_local_id': -1, 'vp': 0}
# ---
# keys for AMAT
# {'C_m': 100.0, 'Ca': 0.0, 'E_L': -70.0, 'I_e': 0.0, 'I_kernel_exc__X__exc_spikes': 0.0, 'I_kernel_inh__X__inh_spikes': 0.0, 'V_m': -70.0, 'V_th_alpha_1': 0.0, 'V_th_alpha_2': 0.0, 'V_th_v': 0.0, 'V_th_v_aux': 0.0, '__P__I_kernel_exc__X__exc_spikes__I_kernel_exc__X__exc_spikes': 0.9048374180359595, '__P__I_kernel_inh__X__inh_spikes__I_kernel_inh__X__inh_spikes': 0.9672161004820059, '__P__V_m__I_kernel_exc__X__exc_spikes': 0.0009468046190356517, '__P__V_m__I_kernel_inh__X__inh_spikes': -0.0009785885685926676, '__P__V_m__V_m': 0.9900498337491681, '__P__V_th_alpha_1__V_th_alpha_1': 0.9900498337491681, '__P__V_th_alpha_2__V_th_alpha_2': 0.9995001249791693, '__P__refr_t__refr_t': 1.0, '__h': 0.1, 'alpha_1': 10.0, 'alpha_2': 5.0, 'beta': -5.0, 'beta_Ca': 0.001, 'element_type': 'neuron', 'frozen': False, 'global_id': 3, 'gsl_abs_error_tol': 1e-06, 'gsl_rel_error_tol': 1e-06, 'local': True, 'model': 'amat_neuron_nestml', 'model_id': 106, 'node_uses_wfr': False, 'omega': 5.0, 'recordables': ['I_kernel_exc__X__exc_spikes', 'I_kernel_inh__X__inh_spikes', 'V_m', 'V_th_alpha_1', 'V_th_alpha_2', 'V_th_v', 'V_th_v_aux', 'refr_t'], 'refr_T': 2.0, 'refr_t': 0.0, 'synaptic_elements': {}, 'tau_1': 10.0, 'tau_2': 200.0, 'tau_Ca': 10000.0, 'tau_V': 5.0, 'tau_m': 10.0, 'tau_syn_exc': 1.0, 'tau_syn_inh': 3.0, 'thread': 0, 'thread_local_id': -1, 'unit_psc': 1.0, 'vp': 0}
# ---
# keys for izhikevich
# {'Ca': 0.0, 'I_e': 0.0, 'U_m': -13.0, 'V_m': -65.0, 'V_min': -1.7976931348623157e+308, 'V_th': 30.0, 'a': 0.02, 'archiver_length': 0, 'b': 0.2, 'beta_Ca': 0.001, 'c': -65.0, 'consistent_integration': True, 'd': 8.0, 'element_type': 'neuron', 'frozen': False, 'global_id': 4, 'ignore_and_spike': False, 'ignore_and_spike_interval': 100.0, 'ignore_and_spike_offset': 1.0, 'local': True, 'model': 'izhikevich', 'model_id': 66, 'node_uses_wfr': False, 'post_trace': 0.0, 'recordables': ['U_m', 'V_m'], 'synaptic_elements': {}, 't_spike': -1.0, 'tau_Ca': 10000.0, 'tau_minus': 20.0, 'tau_minus_triplet': 110.0, 'thread': 0, 'thread_local_id': -1, 'vp': 0}
# ---
# keys for LIF
# ['C_m', 'Ca', 'E_L', 'I_e', 'V_m', 'V_reset', 'V_th', 'archiver_length', 'beta_Ca', 'delta', 'element_type', 'frozen', 'global_id', 'ignore_and_spike', 'ignore_and_spike_interval', 'ignore_and_spike_offset', 'local', 'model', 'model_id', 'node_uses_wfr', 'post_trace', 'recordables', 'rho', 'synaptic_elements', 't_ref', 't_spike', 'tau_Ca', 'tau_m', 'tau_minus', 'tau_minus_triplet', 'tau_syn_ex', 'tau_syn_in', 'thread', 'thread_local_id', 'vp']
# ---

# %% [markdown]
# ### Simulating Model Dynamics and Metric Extraction
#
# This cell executes the core simulation loop for our neuron models within the NEST framework. To validate predictive accuracy against the 2009 QSNMC dataset, we stream identical experimental current vectors into our active models and record the computational spike outputs.
#
# #### Simulation Pipeline:
# 1. **Time-Grid Alignment**: The experimental current timestep is mapped to the internal NEST kernel resolution ($dt = 0.1\text{ ms}$).
# 2. **Stimulus Injection**: A `step_current_generator` translates the sliced $pA$ array into real-time input currents.
# 3. **Recording**: A `spike_recorder` acts as a digital oscilloscope, capturing precise action potential time stamps.
# 4. **Performance Metrics**: The execution computes processing overhead, baseline firing rates ($\text{Hz}$), and extracts data matrices required to calculate the standard coincidence factor ($\Gamma$).

# %%
# --- 1. Select only ONE biological channel (Channel 10) ---
single_channel_voltage = seg_voltage_pA[10] if isinstance(seg_voltage_pA, pd.DataFrame) else seg_voltage_pA[:, 5]

# --- 2. Extract spikes ONLY for this single isolated cell ---
dt = 0.1
experimental_spikes = extract_biological_spikes(single_channel_voltage, dt=dt, threshold_mv=-10.0)
print(f"[Data Prep] Detected {len(experimental_spikes)} biological spikes for Channel 5.")

# --- 3. Align Input Experimental Environment ---
clean_current_values = seg_current.to_numpy().flatten().astype(float)
clean_current_values = clean_current_values[:seg_voltage_pA.shape[0]]
duration_ms = float(len(clean_current_values) * dt)

times = np.round(np.arange(0, len(clean_current_values)) * dt, decimals=4) 

# --- 4. UNIFIED EVALUATION LOOP ---
models_to_test = ['mat2_psc_exp', 'izhikevich', 'iaf_psc_exp', custom_neuron_name] 
model_performance_registry = {}

valid_indices = times >= dt
filtered_times = times[valid_indices]
filtered_values = clean_current_values[valid_indices]

# DEBUG DATA PREP: Ensure input arrays are healthy
print(f"\n[DEBUG DATA] total_duration: {duration_ms} ms | time_steps: {len(times)}")
print(f"[DEBUG DATA] filtered_times: len={len(filtered_times)}, min={filtered_times[0] if len(filtered_times)>0 else 'N/A'}, max={filtered_times[-1] if len(filtered_times)>0 else 'N/A'}")
print(f"[DEBUG DATA] filtered_values: len={len(filtered_values)}, min={np.min(filtered_values)}, max={np.max(filtered_values)}")

# NEST strict requirement check: times must be strictly increasing
if len(filtered_times) > 1 and np.any(np.diff(filtered_times) <= 0):
    print("[WARNING] amplitude_times is NOT strictly increasing! This will crash NEST.")

for model in models_to_test:
    print(f"\nEvaluating Model Architecture: {model}...")
    
    nest.ResetKernel()
    nest.SetKernelStatus({"resolution": dt})

    if model == custom_neuron_name:
        nest.Install(compiled_mod_name)
    
    try:
        if len(filtered_times) == 0:
            raise ValueError("No valid simulation time points found after filtering t >= dt.")

        cg = nest.Create('step_current_generator', params={
            'amplitude_times': filtered_times,
            'amplitude_values': filtered_values,
        })
        
        neuron = nest.Create(model)
        sr = nest.Create('spike_recorder') 

        nest.Connect(cg, neuron)
        nest.Connect(neuron, sr)
        
        # DEBUG BEFORE SIMULATION: Check neuron parameters
        # (Uncomment the line below if you suspect V_m thresholds or reset states are weird)
        # print(f"  [DEBUG NEURON] Initial status: {nest.GetStatus(neuron)[0]}")

        nest.Simulate(duration_ms)

        # Pull model spike arrays out of memory backend safely
        events = sr.get('events')
        model_spikes = events['times'] if 'times' in events else np.array([])

        if not hasattr(model_spikes, '__len__') or isinstance(model_spikes, (float, np.float64)):
            model_spikes = np.array([])

        firing_rate = len(model_spikes) / (duration_ms / 1000.0)
        
        # DEBUG AFTER SIMULATION: Report raw outputs
        print(f"  [DEBUG MODEL] Generated {len(model_spikes)} spikes. Firing rate: {firing_rate:.2f} Hz")
        if len(model_spikes) > 0:
            print(f"  [DEBUG MODEL] First 3 spikes at: {model_spikes[:3]}")

        gamma_score = calculate_coincidence_factor_list(
                [model_spikes],
                experimental_spikes,
                duration_ms
            )

        mean_gamma = np.mean(gamma_score)
        
        model_performance_registry[model] = {
            "firing_rate_hz": firing_rate,
            "gamma_coincidence": mean_gamma,
        }
        
    except Exception as e:
        print(f"  -> CRITICAL ERROR: Framework failed to evaluate {model}. Details: {e}")

# --- 5. COMPREHENSIVE EXPERIMENT SUMMARY ---
print("\n" + "="*50 + "\n FINAL SINGLE-NEURON COMPETITION BENCHMARK\n" + "="*50)
for model, metrics in model_performance_registry.items():
    print(f"Architecture: {model.ljust(20)} | Coincidence Factor (Gamma): {metrics['gamma_coincidence']:.4f} | Rate: {metrics['firing_rate_hz']:.2f} Hz")
# Out:
# [Data Prep] Detected 121 biological spikes for Channel 5.
#
# [DEBUG DATA] total_duration: 14000.0 ms | time_steps: 140000
# [DEBUG DATA] filtered_times: len=139999, min=0.1, max=13999.9
# [DEBUG DATA] filtered_values: len=139999, min=-525.71782, max=1296.1102
#
# Evaluating Model Architecture: mat2_psc_exp...
#   [DEBUG MODEL] Generated 168 spikes. Firing rate: 12.00 Hz
#   [DEBUG MODEL] First 3 spikes at: [14.1 34.1 90.8]
#
# Evaluating Model Architecture: izhikevich...
#   [DEBUG MODEL] Generated 10058 spikes. Firing rate: 718.43 Hz
#   [DEBUG MODEL] First 3 spikes at: [1.4 1.7 2. ]
#
# Evaluating Model Architecture: iaf_psc_exp...
#   [DEBUG MODEL] Generated 333 spikes. Firing rate: 23.79 Hz
#   [DEBUG MODEL] First 3 spikes at: [32.8 66.6 91. ]
#
# Evaluating Model Architecture: amat_neuron_nestml...
#   [DEBUG MODEL] Generated 410 spikes. Firing rate: 29.29 Hz
#   [DEBUG MODEL] First 3 spikes at: [ 6.4 25.3 34.7]
#
# ==================================================
#  FINAL SINGLE-NEURON COMPETITION BENCHMARK
# ==================================================
# Architecture: mat2_psc_exp         | Coincidence Factor (Gamma): 0.2782 | Rate: 12.00 Hz
# Architecture: izhikevich           | Coincidence Factor (Gamma): 0.0238 | Rate: 718.43 Hz
# Architecture: iaf_psc_exp          | Coincidence Factor (Gamma): 0.2273 | Rate: 23.79 Hz
# Architecture: amat_neuron_nestml   | Coincidence Factor (Gamma): 0.2100 | Rate: 29.29 Hz

# %%
models = list(model_performance_registry.keys())
means = [
    float(model_performance_registry[m]["gamma_coincidence"])
    for m in models
]

plt.figure(figsize=(8, 5.5), dpi=100)
colors = ['#7f7f7f', '#a020f0', '#ffa500', '#1f77b4'] # Matches paper aesthetic hues (Gray, Purple, Orange, Blue)

bars = plt.bar(
    models,
    means,
    color=colors[:len(models)],
    edgecolor='black',
    alpha=0.85,
    width=0.45
)

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height + 0.015,
        f"{height:.3f}",
        ha='center',
        fontsize=10
    )

plt.title(r'Predictive Performance Metrics (Coincidence Score $\Gamma$)',
          fontsize=13, pad=15, fontweight='bold')

plt.ylabel(r'Predictive Score, $\Gamma$',
           fontsize=11, labelpad=10)

plt.xlabel('Neuronal Model', fontsize=11, labelpad=10)
plt.ylim(0, 1.1)  # Keeps chart bounds proportional between 0 and 1
plt.grid(axis='y', linestyle='--', alpha=0.4)

plt.tight_layout()
plt.show()
