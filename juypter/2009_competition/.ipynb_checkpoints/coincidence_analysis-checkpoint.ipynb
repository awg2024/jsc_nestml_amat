# %% [markdown]
# # Multi-Model Comparison Using the 2009 Quantitative Single-Neuron Modeling Competition Dataset
#
# This notebook is a validation and extension of Figure 3 from the [Kobayashi et al., 2009](https://nih.gov) paper. In this section of the results, the authors utilise the [2009 Quantitative Single-Neuron Modeling Competition (QSNMC) dataset](https://github.com/InPhyT/Quantitative_Single_Neuron_Modeling_Competition_2009/tree/main) of cortical neurons, feed these neuronal models biological currents, and compare the biological output against the computational output. The comparison is performed using a coincidence-factor equation detailed below.
#
# ### Assessment of Predictive Performance
#
# The performance of the spike time prediction is assessed with a coefficient measuring the degree of coincidence of a model spike train with a real spike train. Among various methods for measuring the similarity between two spike trains, we adopted here the coincidence factor $\Gamma$ (Jolivet et al., 2004, 2006, 2008a; Kobayashi and Shinomoto, 2007), defined by:
#
# $$ \Gamma = \frac{N_{\text{coinc}} - \langle N_{\text{coinc}} \rangle}{\frac{1}{2}(N_{\text{data}} + N_{\text{model}})} \times \frac{1}{1 - 2\nu\Delta} \quad (5) $$
#
# Where:
# * $N_{\text{data}}$ and $N_{\text{model}}$ represent the numbers of spikes in the experimental data and the computational model, respectively.
# * $N_{\text{coinc}}$ is the number of coincident spikes occurring within an allowable temporal window $\Delta$.
# * $\langle N_{\text{coinc}} \rangle = 2\nu\Delta N_{\text{data}}$ is the expected number of coincidences between the data and random Poisson spikes of the given firing rate $\nu$.
#
# By subtracting $\langle N_{\text{coinc}} \rangle$, the baseline coefficient evaluates to approximately $0$ for mutually independent spike trains. The entire coefficient is normalized by dividing by $1 - 2\nu\Delta$ so that $\Gamma = 1$ if all model spikes successfully coincide within the window $\Delta$. In this study, $\Delta$ is chosen to be $2\text{ ms}$.
#
# Each neuron model was tailored to every biological neuron using sample current–voltage data by maximizing the coincidence score $\Gamma$. The model was then tested with a novel current injection dataset to evaluate its predictive capabilities. The final predictive performance was assessed based on the normalized coincidence scores ($\Gamma'$), relative to the experimental trial-to-trial variation, defined by:
#
# $$ \Gamma' = \frac{\Gamma_{\text{model-experiment}}}{\Gamma_{\text{experiment-experiment}}} \quad (6) $$
#
# I've copied in Figure 3.0 from [Kobayashi et al., 2009] below.

# %% [markdown]
# <img src="../images/multi_model_comparision.png" width="1050" height="600">

# %%
# testing imports and mamba env 
import nest
import pynestml
import sys
import numpy as np
import pandas as pd 
import time 
import matplotlib. pyplot as plt 
from pynestml.codegeneration.nest_code_generator_utils import NESTCodeGeneratorUtils
# Out:
#              -- N E S T --
#
#  Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.9.0-post0.dev14
#  Built  : Jul 16 2026 16:13:29
#
#  This program is provided AS IS and comes with NO WARRANTY.
#  See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
# biological data spike detection 
def extract_biological_spikes(voltage_trace, dt=0.1, threshold_mv=-10.0):
    """
    Detects spike times (ms) from raw experimental biological voltage data.
    Finds upward crossings where voltage goes from below threshold to above threshold.
    """
    # Convert pandas Series/DataFrames to standard numpy arrays if necessary
    v = np.array(voltage_trace).flatten()
    
    # Locate all indices where the voltage crosses above the threshold
    crossings = np.where((v[:-1] < threshold_mv) & (v[1:] >= threshold_mv))[0]
    
    # Convert index coordinates to exact physical simulation time stamps (ms)
    # Adding 1 aligns it on the grid with the post-crossing value
    biological_spike_times = (crossings + 1) * dt
    
    return biological_spike_times   #  returning a list of the spike times. 

def calculate_coincidence_factor_list(models_spikes, data_spikes, duration_ms, delta_ms=2.0):   #  delta as specified in the paper. 
    """
    Calculates the coincidence factor for multiple models against a single experimental dataset.
    
    Parameters:
    - models_spikes: A list of lists/arrays, where each element contains spike times for a specific model.
    - data_spikes: List/array of experimental data spike times.
    - duration_ms: Total duration of the recording in milliseconds.
    - delta_ms: Temporal tolerance window in milliseconds (default: 2.0).
    
    Returns:
    - A list of float values representing the gamma coincidence factor for each model.
    """
    N_data = len(data_spikes)
    duration_sec = duration_ms / 1000.0
    delta_sec = delta_ms / 1000.0
    
    # Pre-calculate data-dependent constants to save computation time
    if N_data == 0:
        return [0.0] * len(models_spikes)
        
    nu = N_data / duration_sec
    expected_coinc = 2 * nu * delta_sec * N_data
    norm_factor = 1.0 - (2 * nu * delta_sec)
    
    results = []
    for model_spikes in models_spikes: # Loop through each model's spike train
        N_model = len(model_spikes)
        
        # Check if model is empty or if normalisation collapses
        if N_model == 0 or norm_factor <= 0 or (N_data + N_model) == 0:
            results.append(0.0)
            continue
            
        # Count coincidences using a window search
        N_coinc = 0
        matched_indices = set()
        for s_data in data_spikes:
            for i, s_model in enumerate(model_spikes):
                if i not in matched_indices and abs(s_model - s_data) <= delta_ms:
                    N_coinc += 1
                    matched_indices.add(i)
                    break
                    
        # Calculate Gamma coincidence formula
        gamma = ((N_coinc - expected_coinc) / (0.5 * (N_data + N_model))) * (1.0 / norm_factor)
        results.append(max(gamma, 0.0))
        
    return results

from itertools import combinations


def calculate_reliability(
        voltage_data,
        dt_ms=0.1,
        threshold_mv=-10.0,
        delta_ms=2.0
):

    """
    Calculate intrinsic biological reliability:
    Γexperiment-experiment
    """

    spike_trains = []


    # Extract spikes from every repetition

    for rep in range(voltage_data.shape[1]):

        spikes = extract_biological_spikes(
            voltage_data[:,rep],
            dt=dt_ms,
            threshold_mv=threshold_mv
        )

        spike_trains.append(spikes)


    gamma_values = []


    # all pairwise comparisons

    for i,j in combinations(
        range(len(spike_trains)),
        2
    ):

        gamma = calculate_coincidence_factor_list(
            [
                spike_trains[j]
            ],
            spike_trains[i],
            len(voltage_data)*dt_ms
        )[0]


        gamma_values.append(gamma)


    reliability = np.mean(gamma_values)


    return reliability, spike_trains

# %% [markdown]
# ### Loading and segmenting the 2009 challenge A dataset per READ_ME.md
#
# Training set is first 39 s, test set is last 21 seconds. Injected current waveform in pA are provided for both training and test phases. Voltage responses are provided for the training but not the test phase.

# %%
# Load data
current_path = r"data_challengeA/current.csv"
voltage_path = r"data_challengeA/voltage_allrep.csv"

# load in raw txt files 
raw_current = pd.read_csv(
    current_path,
    header=None,
    names=["Current"]
)

raw_voltage = pd.read_csv(
    voltage_path,
    header=None,
    sep=r"\s+"
)

# Convert to arrays
current = raw_current["Current"].values
voltage = raw_voltage.values

# Sampling
dt = 1e-4     # seconds
fs = 1/dt
print(f"Sampling frequency: {fs} Hz")

# Time vectors
t_current = np.arange(len(current)) * dt
t_voltage = np.arange(len(voltage)) * dt

# train/test split 
train_duration = 39.0      # seconds
test_duration = 21.0       # seconds

train_samples = int(train_duration / dt)
test_samples = int(test_duration / dt)

print(f"Training samples: {train_samples}")
print(f"Testing samples: {test_samples}")

# defining training dataset 
t_train = t_current[:train_samples]
I_train = current[:train_samples]
V_train = voltage[:train_samples].mean(axis=1) # average the 13 channels / neurons voltages

# defining testing dataset 
t_test = t_current[train_samples:train_samples + test_samples]
I_test = current[train_samples:train_samples + test_samples]
# No voltage response supplied for Challenge A, to enable neuronal model predictions 
V_test = None

# verify the readme 
print(f"Current duration : {len(current) * dt:.1f} s")
print(f"Voltage duration : {len(voltage) * dt:.1f} s")

training_dataset = {
    "time": t_train,
    "current": I_train,
    "voltage": V_train,
}

testing_dataset = {
    "time": t_test,
    "current": I_test,
    "voltage": None,
}


# plotting injected currents across training and testing datasets 
plt.figure(figsize=(12,4))
plt.plot(
    t_train,
    I_train,
    label="Training current",
    color="tab:blue"
)

plt.plot(
    t_test,
    I_test,
    label="Testing current",
    color="tab:orange"
)

plt.axvline(
    train_duration,
    color="black",
    linestyle="--",
    label="Train/Test split"
)

plt.xlabel("Time (s)")
plt.ylabel("Injected current (pA)")
plt.title("Injected current waveform")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# plotting voltage response (avg across 13 channels) 
plt.figure(figsize=(12,4))
plt.plot(
    t_train,
    V_train,
    color="tab:red",
    label="Membrane voltage"
)

plt.xlabel("Time (s)")
plt.ylabel("Membrane voltage (mV)")
plt.title("Training voltage response")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()


# combning both plots above together, overlaying the input currents and voltage responses for training 
# no injected current df for testing set. 
fig, ax1 = plt.subplots(figsize=(12,5))
ax1.plot(
    t_train,
    I_train,
    color="tab:blue",
    label="Training current"
)

ax1.plot(
    t_test,
    I_test,
    color="tab:orange",
    label="Testing current"
)

ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Injected current (pA)")
ax1.axvline(
    train_duration,
    color="black",
    linestyle="--"
)

# Voltage
ax2 = ax1.twinx()
ax2.plot(
    t_train,
    V_train,
    color="tab:red",
    linewidth=1,
    label="Training voltage"
)

ax2.set_ylabel("Membrane voltage (mV)")

# Combined legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()

ax1.legend(
    lines1 + lines2,
    labels1 + labels2,
    loc="upper right"
)
fig.tight_layout()
plt.show()
# Out:
# Sampling frequency: 10000.0 Hz
# Training samples: 390000
# Testing samples: 210000
# Current duration : 60.0 s
# Voltage duration : 39.0 s

# %% [markdown]
# ### Installing and Building NEST models neuronal models
#
# This step is to build the different neuronal models we will be testing for and to install the NESTML AMAT model .

# %%
# Using sys.prefix targets your active conda-forge environment root directory
nest_path = sys.prefix

# Compile the custom nestml template file
compiled_mod_name, custom_neuron_name = NESTCodeGeneratorUtils.generate_code_for(
    "../neurons_nestml/amat_neuron.nestml",
    module_name="nestml_amat_module",   
    logging_level="INFO")

print(f"[NESTML] Compilation Complete.")
print(f" Dynamically Compiled Module Name: {compiled_mod_name}")
print(f" Target Internal Neuron Name to Instantiate: {custom_neuron_name}")

# Reset the NEST kernel to a completely clean state.
nest.ResetKernel()

# Install your custom dynamic module into the active NEST kernel
nest.Install(compiled_mod_name)

# Only display errors from NEST (suppresses warnings and info messages).
nest.set_verbosity("M_ERROR")

# Configure parameters for the simulation kernel.
nest.SetKernelStatus({"resolution": 0.1, "local_num_threads": 1, "rng_seed": 12345})

n = nest.Create('mat2_psc_exp',
    params={
        "omega": -65.0,
        "alpha_1": 180.0,
        "alpha_2": 1.0,
    },
)
print("keys for MAT")
print(n.get())
print("---")


# From original paper - can we maybe play around with these parameters? 
# Model parameters: HH: C=86pF,g =750nS,g =210nS,g =210nS,g =0.6nS, Na Kd M L
# V =−61mV;LIF:θ=25mV;
# SRM:α=12mV,ω=13mV,τ =50ms; Tα
# MAT*:α =37mV,α =2mV,ω=19mV

# Create the neuron using its internal target name variable
n2 = nest.Create(
    custom_neuron_name,
    params={
        "omega": -65.0,
        "alpha_1": 180.0,
        "alpha_2": 3.0,
        "beta": 0.2,
        # >0 negative feedback
        # <0 positive feedback 
    },
)
print("keys for NESTML AMAT")
print(n2.get())
print("---")

n3 = nest.Create('izhikevich')
print("keys for izhikevich")
print(n3.get())
print("---")

n4 = nest.Create('iaf_psc_exp')
print("keys for LIF")
print(list(n4.get().keys()))
print("---")

n5 = nest.Create('amat2_psc_exp')
print("keys for NEST AMAT")
print(list(n5.get().keys()))

# %% [markdown]
# ### Simulating Model Dynamics and Metric Extraction
#
# This cell executes the core simulation loop for our neuron models within the NEST framework. To validate predictive accuracy against the 2009 QSNMC dataset, we stream identical experimental current vectors into our active models and record the computational spike outputs.
#
# #### Simulation Pipeline:
# 1. **Time-Grid Alignment**: The experimental current timestep is mapped to the internal NEST kernel resolution ($dt = 0.1\text{ ms}$).
# 2. **Stimulus Injection**: A `step_current_generator` translates the sliced $pA$ array into real-time input currents.
# 3. **Recording**: A `spike_recorder` acts as a digital oscilloscope, capturing precise action potential time stamps.
# 4. **Performance Metrics**: The execution computes processing overhead, baseline firing rates ($\text{Hz}$), and extracts data matrices required to calculate the standard coincidence factor ($\Gamma$).

# %%
models_to_test = [
    "mat2_psc_exp",
    "izhikevich",
    "iaf_psc_exp",
    custom_neuron_name
]

# dictionary to store results

model_performance_registry = {}

# ============================================================
# Select specific biological windows only
# ============================================================

dt_ms = 0.1
fs = 1000 / dt_ms   # Hz


# ============================================================
# Select biological voltage channel
# ============================================================

channel = 5

full_voltage = voltage[:, channel]

full_current = current[:len(full_voltage)]



# Extract selected sections

voltage_segments = np.concatenate(
    [
        full_voltage[s]
        for s in segments
    ]
)


current_segments = np.concatenate(
    [
        full_current[s]
        for s in segments
    ]
)



print("\nSelected data")
print("-----------------------------")
print(
    f"Voltage samples: {len(voltage_segments)}"
)

print(
    f"Current samples: {len(current_segments)}"
)


duration_ms = len(current_segments) * dt_ms

print(
    f"Simulation duration: {duration_ms:.2f} ms "
    f"({duration_ms/1000:.3f} s)"
)



# ============================================================
# Extract biological spikes
# ============================================================

experimental_spikes = extract_biological_spikes(
    voltage_segments,
    dt=dt_ms,
    threshold_mv=-10.0
)


print(
    f"Detected biological spikes: {len(experimental_spikes)}"
)



# ============================================================
# Prepare NEST current
# ============================================================

times = (
    np.arange(len(current_segments))
    * dt_ms
)


# remove zero time

valid = times >= dt_ms


filtered_times = times[valid]

filtered_values = current_segments[valid]



if np.any(np.diff(filtered_times) <= 0):
    raise ValueError(
        "NEST times not strictly increasing"
    )


print("\nNEST")
print("-----------------------------")
print(
    f"Current points: {len(filtered_times)}"
)

print(
    f"Time range: {filtered_times[0]}-{filtered_times[-1]} ms"
)


R, all_biological_spikes = calculate_reliability(
    voltage,
    dt_ms=0.1,
    threshold_mv=-10.0
)


print(
    f"Intrinsic biological reliability R = {R:.4f}"
)

# ============================================================
# 5. Run simulations
# ============================================================

for model in models_to_test:


    print("\n" + "-"*50)
    print(f"Evaluating model: {model}")


    nest.ResetKernel()


    nest.SetKernelStatus(
        {
            "resolution": dt_ms
        }
    )


    # install custom model if required

    if model == custom_neuron_name:

        nest.Install(
            compiled_mod_name
        )


    try:


        # -----------------------------
        # Current generator
        # -----------------------------

        current_generator = nest.Create(
            "step_current_generator",
            params={
                "amplitude_times": filtered_times,
                "amplitude_values": filtered_values,
            }
        )


        # neuron

        neuron = nest.Create(
            model
        )


        # spike recording

        spike_recorder = nest.Create(
            "spike_recorder"
        )


        # connect

        nest.Connect(
            current_generator,
            neuron
        )


        nest.Connect(
            neuron,
            spike_recorder
        )


        # simulate

        nest.Simulate(
            duration_ms
        )



        # ====================================================
        # Extract model spikes
        # ====================================================

        events = spike_recorder.get(
            "events"
        )


        if "times" in events:

            model_spikes = np.array(
                events["times"]
            )

        else:

            model_spikes = np.array([])



        # ====================================================
        # Metrics
        # ====================================================

        firing_rate = (
            len(model_spikes)
            /
            (duration_ms / 1000)
        )


        raw_gamma = calculate_coincidence_factor_list(
            [model_spikes],
            experimental_spikes,
            duration_ms
        )

        raw_gamma = np.mean(raw_gamma)
        
        gamma_prime = raw_gamma / R

        # Store results

        model_performance_registry[model] = {

            "spike_count":
                len(model_spikes),

            "firing_rate_hz":
                firing_rate,

            "gamma":
                gamma_prime,

            "model_spikes":
                model_spikes
        }


        print(
            f"Spikes generated: {len(model_spikes)}"
        )

        print(
            f"Firing rate: {firing_rate:.2f} Hz"
        )

        print(
            f"Gamma: {gamma_prime:.4f}"
        )



    except Exception as e:


        print(
            f"FAILED: {model}"
        )

        print(e)



# ============================================================
# 6. Final benchmark table
# ============================================================


print("\n")
print("="*70)
print("FINAL BIOLOGICAL TRAINING BENCHMARK")
print("="*70)


for model, result in model_performance_registry.items():

    print(
        f"{model:<25}"
        f" spikes={result['spike_count']:<6}"
        f" rate={result['firing_rate_hz']:>7.2f} Hz   "
        f"gamma={result['gamma']:.4f}"
    )

# %%
models = list(model_performance_registry.keys())
means = [
    float(model_performance_registry[m]["gamma"])
    for m in models
]

plt.figure(figsize=(8, 5.5), dpi=100)
colors = ['#7f7f7f', '#a020f0', '#ffa500', '#1f77b4'] # Matches paper aesthetic hues (Gray, Purple, Orange, Blue)

bars = plt.bar(
    models,
    means,
    color=colors[:len(models)],
    edgecolor='black',
    alpha=0.85,
    width=0.45
)

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height + 0.015,
        f"{height:.3f}",
        ha='center',
        fontsize=10
    )

plt.title(r'Predictive Performance Metrics (Coincidence Score $\Gamma$)',
          fontsize=13, pad=15, fontweight='bold')

plt.ylabel(r'Predictive Score, $\Gamma$',
           fontsize=11, labelpad=10)

plt.xlabel('Neuronal Model', fontsize=11, labelpad=10)
plt.ylim(0, 1.5)  # Keeps chart bounds proportional between 0 and 1
plt.grid(axis='y', linestyle='--', alpha=0.4)

plt.tight_layout()
plt.show()
